# %%
from config import access_token_omdb3, access_token_tmdb
import time
import requests
import json
import pandas as pd
import ast
import numpy as np
from datetime import datetime
import re
import sqlite3

# %% [markdown]
# ### Obtain List of Movie Titles and Prepare for API ###

# %%
# read Rotten Tomatoes csv file data to pandas dataframe
df = pd.read_csv('rotten_tomatoes.csv')

# pull the movie titles from the pandas dataframe into a list
movies_titles = df['Movie Title'].tolist()

# %%
# add '+' to movie titles for API query
movies = [movie.replace(' ','+') for movie in movies_titles]

# %%
# use regex to remove the content between the parantheses to create the final movie titles query list
movies_search = []
for movie in movies:
    movies_search.append(re.sub(r" ?\([^)]+\)", "", movie))

# %% [markdown]
# ### Make API Calls ###

# %%
# test omdb call with one ping first
def omdb_call():
    
    url = 'https://www.omdbapi.com/'
    
    params = {'t': 'Chicken+Run',
                    'type': 'movie',
                    'plot': 'short',
                     'apikey': access_token_omdb1}
        
    # make api call to obtain data
    response = requests.get(url, params=params)
            
    return response.json()

# %%
omdb_call()
# Out:
# {'Title': 'Chicken Run',
#  'Year': '2000',
#  'Rated': 'G',
#  'Released': '23 Jun 2000',
#  'Runtime': '84 min',
#  'Genre': 'Animation, Adventure, Comedy, Drama, Family',
#  'Director': 'Peter Lord, Nick Park',
#  'Writer': "Peter Lord (original story), Nick Park (original story), Karey Kirkpatrick (screenplay), Mark Burton (additional dialogue), John O'Farrell (additional dialogue)",
#  'Actors': 'Phil Daniels, Lynn Ferguson, Mel Gibson, Tony Haygarth',
#  'Plot': 'When a cockerel apparently flies into a chicken farm, the chickens see him as an opportunity to escape their evil owners.',
#  'Language': 'English',
#  'Country': 'UK, USA, France',
#  'Awards': 'Nominated for 1 Golden Globe. Another 23 wins & 25 nominations.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BY2UyYjFkNzAtYzIyMC00MGI1LTlkNDktNzUyOGQ5NTI2ZGFjXkEyXkFqcGdeQXVyNTUyMzE4Mzg@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.0/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '97%'},
#   {'Source': 'Metacritic', 'Value': '88/100'}],
#  'Metascore': '88',
#  'imdbRating': '7.0',
#  'imdbVotes': '161,577',
#  'imdbID': 'tt0120630',
#  'Type': 'movie',
#  'DVD': '21 Nov 2000',
#  'BoxOffice': '$106,604,314',
#  'Production': 'Dreamworks Pictures',
#  'Website': 'http://www.reel.com/reel.asp?node=chickenrun',
#  'Response': 'True'}

# %%
# function to make multiple calls to OMDB API by looping through list of movie titles
def omdb_calls():
    
    max_calls = 800
    counter = 0
    
    while counter <= max_calls:
        for movie in movies_search:
            try:
                if True:
                    url = 'https://www.omdbapi.com/'
                    params = {'t': movie,
                            'type': 'movie',
                             'apikey': access_token_omdb3}
                    # make api call to obtain data
                    response = requests.get(url, params=params)
                    counter+=1

                    # write information from api call response in json file as it comes in
                    with open('omdb_data.json', 'w') as f:
                        f.write(str(response.json()))
                        
                else:
                    print('Rate Limit Reached')
                    counter = 0
            except:
                pass
        
    return response.status_code

# %%
# function to make calls to The Movie DB API by looping through list of movie titles
def tmdb_calls():
    movie_info = []
    counter = 0

    for movie in movies_search:
        try:
            if counter <=40:
                URL = 'https://api.themoviedb.org/3/search/movie?api_key={}&query={}'.format(access_token_tmdb, movie)
                response = requests.get(URL)
                movie_info.append(response.json())
                counter += 1
            else:
                print("Rate Limit Reached")
                time.sleep(10)
                counter = 0
        except:
            pass
    return movie_info

# %%
# obtain list of data from TMDB API call response
movie_info = tmdb_calls()
# Out:
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached
# Rate Limit Reached

# %% [markdown]
# ### Work with API Response Data in Pandas DataFrame ###

# %%
# convert movie_info list to pandas dataframe
movies_df = pd.DataFrame(movie_info)

# %%
movies_df.head()
# Out:
#    page                                            results  status_code  \
# 0   1.0  [{'vote_count': 2438, 'id': 7443, 'video': Fal...          NaN
# 1   1.0  [{'vote_count': 97, 'id': 10697, 'video': Fals...          NaN
# 2   1.0  [{'vote_count': 6, 'id': 41276, 'video': False...          NaN
# 3   1.0  [{'vote_count': 156, 'id': 25538, 'video': Fal...          NaN
# 4   1.0  [{'vote_count': 136, 'id': 14295, 'video': Fal...          NaN
#
#   status_message  total_pages  total_results
# 0            NaN          1.0            3.0
# 1            NaN          1.0            1.0
# 2            NaN          1.0            1.0
# 3            NaN         38.0          749.0
# 4            NaN          1.0            1.0

# %%
movies_df.tail()
# Out:
#       page                                            results  status_code  \
# 1850   1.0  [{'vote_count': 1855, 'id': 480530, 'video': F...          NaN
# 1851   1.0  [{'vote_count': 5, 'id': 490780, 'video': Fals...          NaN
# 1852   1.0  [{'vote_count': 4, 'id': 475220, 'video': Fals...          NaN
# 1853   1.0  [{'vote_count': 267, 'id': 474395, 'video': Fa...          NaN
# 1854   1.0  [{'vote_count': 17067, 'id': 118340, 'video': ...          NaN
#
#      status_message  total_pages  total_results
# 1850            NaN          1.0            2.0
# 1851            NaN          1.0            2.0
# 1852            NaN          1.0            6.0
# 1853            NaN          1.0            1.0
# 1854            NaN          2.0           35.0

# %%
movies_df.shape
# Out:
# (1855, 6)

# %%
# function to convert values to workable data
def de_string ():
    if not np.nan:
        df['results'].apply(lambda x : ast.literal_eval(x))
    else:
        pass
    return df['results']

# %%
# create a list of the values from the pandas series of results
mdf = movies_df['results'].get_values().tolist()

# %%
# loop through list to pull out dicitionaries into a new list
results1 = []
for i in range(len(mdf)):
    if type(mdf[i]) == list:
        for j in range(len(mdf[i])):
            results1.append(mdf[i][j])
    else:
        results1.append(mdf[i])

# %%
results1
# Out:
# [{'vote_count': 2438,
#   'id': 7443,
#   'video': False,
#   'vote_average': 6.6,
#   'title': 'Chicken Run',
#   'popularity': 13.991,
#   'poster_path': '/z0MafJgUnVyVbczicYMkPKKHkBi.jpg',
#   'original_language': 'en',
#   'original_title': 'Chicken Run',
#   'genre_ids': [16, 35, 10751],
#   'backdrop_path': '/b0Zlbk19oTLjKPvb807suPFKBtN.jpg',
#   'adult': False,
#   'overview': 'Having been hopelessly repressed and facing eventual certain death at the British chicken farm where they are held, Ginger the chicken along with the help of Rocky the American rooster decide to rebel and lead their fellow chickens in a great escape from the murderous farmers Mr. and Mrs. Tweedy and their farm of doom.',
#   'release_date': '2000-06-21'},
#  {'vote_count': 0,
#   'id': 520758,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Chicken Run 2',
#   'popularity': 1.462,
#   'poster_path': '/wQJW29RIMFQFV46eTLLmTrorjDB.jpg',
#   'original_language': 'en',
#   'original_title': 'Chicken Run 2',
#   'genre_ids': [16],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A sequel to the 2000 film, "Chicken Run."',
#   'release_date': '2020-06-12'},
#  {'vote_count': 0,
#   'id': 495607,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Running Around Like A Chicken With Its Head Cut Off',
#   'popularity': 0.6,
#   'poster_path': '/vNTe1R0zg9kEV8bBLEpdovb5Zvr.jpg',
#   'original_language': 'en',
#   'original_title': 'Running Around Like A Chicken With Its Head Cut Off',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Les Blank's first student film, made while at USC, starring Gail Blank, Pieter Van Deusen and Les himself. This short pays homage to Ingmar Bergman's Seventh Seal, the film that inspired Blank to become a filmmaker.",
#   'release_date': '1960-01-01'},
#  {'vote_count': 97,
#   'id': 10697,
#   'video': False,
#   'vote_average': 6.7,
#   'title': 'The Taste of Others',
#   'popularity': 5.907,
#   'poster_path': '/k9R6Omadvp57EoQ4x9nNneig1Nv.jpg',
#   'original_language': 'fr',
#   'original_title': 'Le Goût des autres',
#   'genre_ids': [18, 35, 10749],
#   'backdrop_path': '/evNvMSUYYjZBluXuZEV9JpqNUel.jpg',
#   'adult': False,
#   'overview': 'Agnès Jaoui co-writes and directs this romantic comedy of manners set in France\'s rustic Provence. Unpolished and ultra-pragmatic industrialist Jean-Jacques Castella (co-scripter Jean-Pierre Bacri) reluctantly attends Racine\'s tragedy "Berenice" in order to see his niece play a bit part. He is taken with the play\'s strangely familiar-looking leading lady Clara Devaux (Anne Alvaro). During the course of the show, Castella soon remembers that he once hired and then promptly fired the actress as an English language tutor. He immediately goes out and signs up for language lessons. Thinking that he is nothing but an ill-tempered philistine with bad taste, Clara rejects him until Castella charms her off her feet.',
#   'release_date': '2000-03-01'},
#  {'vote_count': 6,
#   'id': 41276,
#   'video': False,
#   'vote_average': 6,
#   'title': 'The Life and Times of Hank Greenberg',
#   'popularity': 0.6,
#   'poster_path': '/q5L7XLJ4ylDAs0txMMREbwuoudD.jpg',
#   'original_language': 'en',
#   'original_title': 'The Life and Times of Hank Greenberg',
#   'genre_ids': [99, 10751],
#   'backdrop_path': '/WeDJNcoIJDC6FvcC19dEHz09XR.jpg',
#   'adult': False,
#   'overview': 'The story of Baseball Hall-of-Famer Hank Greenberg is told through archival film footage and interviews with Jewish and non-Jewish fans, his former teammates, his friends, and his family. As a great first baseman with the Detroit Tigers, Greenberg endured antisemitism and became a hero and source of inspiration throughout the Jewish community, not incidentally leading the Tigers to Major League dominance in the 1930s. Written by George S. Davis',
#   'release_date': '2000-01-12'},
#  {'vote_count': 156,
#   'id': 25538,
#   'video': False,
#   'vote_average': 8,
#   'title': 'Yi Yi',
#   'popularity': 6.59,
#   'poster_path': '/hTPkCpK9SLGDMXRbUwzoep0MxOx.jpg',
#   'original_language': 'zh',
#   'original_title': '一一',
#   'genre_ids': [18, 10749],
#   'backdrop_path': '/r3IJLWkORZWJD7v9yT4yFzp2XQ6.jpg',
#   'adult': False,
#   'overview': "Each member of a family in Taipei asks hard questions about life's meaning as they live through everyday quandaries.",
#   'release_date': '2000-09-20'},
#  {'vote_count': 40,
#   'id': 25474,
#   'video': False,
#   'vote_average': 6.8,
#   'title': 'Accident',
#   'popularity': 3.891,
#   'poster_path': '/8CwreRof98cUJFJhQlqc5YVdZ7C.jpg',
#   'original_language': 'cn',
#   'original_title': 'Yi ngoi',
#   'genre_ids': [28, 18, 53],
#   'backdrop_path': '/ryTTmKkuAndi5U58mlSlSY0SAA1.jpg',
#   'adult': False,
#   'overview': 'A self-styled accident choreographer, the Brain is a professional hitman who kills his victims by trapping them in well crafted accidents that look like unfortunate mishaps but are in fact perfectly staged acts of crime. When the teams next assignment goes disastrously wrong, Brain begins to suspect that someone else has planned an ‘accident’ on them.',
#   'release_date': '2009-09-24'},
#  {'vote_count': 3,
#   'id': 337302,
#   'video': False,
#   'vote_average': 5,
#   'title': '10000 Years Later',
#   'popularity': 1.112,
#   'poster_path': '/nyQBg6NsxpFmTAMBPaT69MBdh5w.jpg',
#   'original_language': 'zh',
#   'original_title': 'Yi wan nian yi hou',
#   'genre_ids': [14, 16],
#   'backdrop_path': '/waouCyGVrZiqm605YjqPLzNAyMC.jpg',
#   'adult': False,
#   'overview': 'Hundreds of thousands of years after the collapse of civilization, the world is a post-tech wasteland, and is inhabited by humanoid tribes. The Peace held between them is threatened by the return of Wushen, an evil shape-shifting ghost of modern technology. Wushen threatens to enslave the world population. Zhuma, a ten-year-old girl is the heroine of the story, accompanied by Zhanggong, her lion-like Tibetan Mastiff dog. Chosen, and helped by a ethereal goddess she must assemble a band of allies from the surviving tribes to fight Wushen, and stop him from gaining control over an ancient power.',
#   'release_date': '2015-03-27'},
#  {'vote_count': 2,
#   'id': 74273,
#   'video': False,
#   'vote_average': 3.5,
#   'title': 'Vampire Settle On Police Camp',
#   'popularity': 1.569,
#   'poster_path': '/derUlaU0472CfhHgXMs6G1ApYDM.jpg',
#   'original_language': 'en',
#   'original_title': 'Yi mei dao gu',
#   'genre_ids': [27, 28],
#   'backdrop_path': '/t09RCQ6elr7pW0KE0vXolKYgm4H.jpg',
#   'adult': False,
#   'overview': 'Police School is haunted. Chan Sir and Tong Sir in order to drive out the ghosts, so they find out nine police, who is the dragon-year born, to practice an array. Because of arrogant of Inspector Li Lan Yuk, makes others with bad feeling. They decide to play a trick on her and have lots of joke. They know the goal of training is to seize the ghosts, they all left the training. But the camp is already controlled by the ghosts, causes they stay here to help Chan to seize the ghosts. In Lunar night, on July 14, Chan unable to seize the ghosts, Madam Lee takes out the family secrets and turns into a Taoist priestess to fight with the ghosts. At last, Lee and master drive out all the ghosts',
#   'release_date': '1990-06-07'},
#  {'vote_count': 1,
#   'id': 64985,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Black Lizard',
#   'popularity': 1.4,
#   'poster_path': '/nA5RxYiVb6Uf6XMOnAq91pmoFsg.jpg',
#   'original_language': 'en',
#   'original_title': 'Hei xi yi',
#   'genre_ids': [28, 18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Director Chu Yuan uses two editors and three martial arts choreographers to tell a maacabre tale of kidnapping, murder, frame-ups, and even being buried alive. Swordsmen and women struggle to save their true loves...and their sanity.',
#   'release_date': '1981-11-26'},
#  {'vote_count': 0,
#   'id': 535690,
#   'video': False,
#   'vote_average': 0,
#   'title': 'A Strange Woman',
#   'popularity': 1.4,
#   'poster_path': None,
#   'original_language': 'zh',
#   'original_title': 'Yi dai yao ji',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Not seen in Hong Kong for many years, A Strange Woman was Li Pingqian's first film at Great Wall Film Studio. Adapted from the play La Tosca by French playwright Victorien Sardou, opera star Xiao Xiangshui (Bai Guang) helps her lover, a revolutionary, to escape from warlords. She finesses with both the head of the secret service (Yan Jun) and her lover's wife, but things do not turn out as planned. Li changed his usual pace to encompass a more conventional and dramatic film plot. Bold and flirtatious in her role, Bai Guang is equally over the top in appearance as Yan Jun. The tension in winning the heroine over drives the plot more than the themes of patriotism and loyalty in love.",
#   'release_date': '1950-01-01'},
#  {'vote_count': 0,
#   'id': 583787,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Yi chu hao xi',
#   'popularity': 1.4,
#   'poster_path': None,
#   'original_language': 'zh',
#   'original_title': 'Yi chu hao xi',
#   'genre_ids': [35, 18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '2018-08-09'},
#  {'vote_count': 5,
#   'id': 107714,
#   'video': False,
#   'vote_average': 5.9,
#   'title': 'Return of the Bastard Swordsman',
#   'popularity': 1.346,
#   'poster_path': '/9ygquhVImOG8gED7STeTc6tDQGe.jpg',
#   'original_language': 'en',
#   'original_title': 'Bu yi shen xiang',
#   'genre_ids': [28],
#   'backdrop_path': '/r1MWgiOK1sv3BLgu3jiFcyhoL4M.jpg',
#   'adult': False,
#   'overview': 'Just when audiences thought the director couldn\'t get more spectacular and outrageous, he unleashed this eye-filling, mind-bending "Martial Arts World" sequel of clan rivalries, ninja atrocities, wizard sorceries, and the mythical Silkworm style that changes our hero into a veritable Spider-swordsman. The screen practically explodes with colorful characters and kung-fu -- all directed, co-written, and co-choreographed by Lu Chun-ku, and showcasing some of the best Shaw Brothers action stars. The original Bastard Swordsman was just the beginning, this superlative cult classic that out-phantasmagoricals the original.',
#   'release_date': '1984-05-08'},
#  {'vote_count': 7,
#   'id': 50718,
#   'video': False,
#   'vote_average': 7.9,
#   'title': 'One Day',
#   'popularity': 1.304,
#   'poster_path': '/uMFZchEhaNd3NSIkWfnTu4MkBVN.jpg',
#   'original_language': 'zh',
#   'original_title': '有一天',
#   'genre_ids': [18, 10749, 878],
#   'backdrop_path': '/dMmMK5gWmVlCBXT3SMfkh7UAjXm.jpg',
#   'adult': False,
#   'overview': 'A woman is transported into a world as strange and beautiful as her dreams in this fantasy. Singing (Nikki Hsin-Ying Hsieh), who comes from a family of poor shopkeepers, earns her living as a cleaning woman on a ferry that services a military base. Singing has a recurring dream in which she meets a handsome stranger who speaks in language she cannot understand, and one day on the ferry she meets Tsai Hsien-tsung (Bryan Chang), a soldier who resembles the man in her dreams. The soldier is immediately smitten with Singing, and when the power goes out on the ferry, the two are thrown into a strange netherworld where they sail to South America on a deserted vessel as Singing loses her heart to the military man.',
#   'release_date': '2010-02-07'},
#  {'vote_count': 0,
#   'id': 355421,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Auntie Lan',
#   'popularity': 0.877,
#   'poster_path': '/44VMoHZUepXE6UwM8w8vwyTiVJG.jpg',
#   'original_language': 'en',
#   'original_title': 'Lan yi',
#   'genre_ids': [10749, 18],
#   'backdrop_path': '/aBCuNe1uw5VtbRikKWQ9eTQZ4lq.jpg',
#   'adult': False,
#   'overview': 'A young woman lost her fiancé from the plane clash , later she discover that she becomes pregnant with his baby.She question herself what should she do between keep the child safe until she give a birth or she abortion the child.',
#   'release_date': '1967-03-02'},
#  {'vote_count': 1,
#   'id': 237403,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Iron Head',
#   'popularity': 1.12,
#   'poster_path': '/p3ne2yRsPj1zoPO9jcVJtb5OAfB.jpg',
#   'original_language': 'en',
#   'original_title': 'Wu long jiao yi',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A bumbling martial arts teacher has the skills but lacks the confidence to use them.  Run out of town by some ne'er-do-wells, he sets out on some comic adventures as he travels the countryside.  Taking up some companions that are as bumbling as he is, the group seems to stumble into one misadventure after another.  Will our hearty band eventually prove their worth with their skills and bring their enemies to justice?",
#   'release_date': '1974-06-07'},
#  {'vote_count': 0,
#   'id': 316955,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Oh! What a Family',
#   'popularity': 1.09,
#   'poster_path': '/u5lq8MCBg1ZkHKyvGgxEoEoCFNE.jpg',
#   'original_language': 'zh',
#   'original_title': 'Qiao zhe yi jiazi',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '1979-01-01'},
#  {'vote_count': 0,
#   'id': 360609,
#   'video': False,
#   'vote_average': 0,
#   'title': 'House of the Invisibles',
#   'popularity': 0.6,
#   'poster_path': '/5xwbRJilNl1d9G5L8C4LcydagJM.jpg',
#   'original_language': 'cn',
#   'original_title': 'Yi Lou Yi Gui',
#   'genre_ids': [27],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The inhabitants of a decrepit inner-city tenement building are terrified to discover that the malevolent spirit of a former tenant has been summoned when one of the current residents broke an unspoken vow. Now, as demolition day draws near, the enraged entity sets out to cause as much mischief as possible before the wrecking ball strikes.',
#   'release_date': '2007-01-25'},
#  {'vote_count': 85,
#   'id': 34179,
#   'video': False,
#   'vote_average': 6.5,
#   'title': '14 Blades',
#   'popularity': 4.96,
#   'poster_path': '/dAMh7PtMRpjLLiwdWyzOAwZucPI.jpg',
#   'original_language': 'zh',
#   'original_title': '錦衣衛',
#   'genre_ids': [18, 28, 53],
#   'backdrop_path': '/xji4jDRASuAUsJCPk70yotMFcfo.jpg',
#   'adult': False,
#   'overview': 'Trained in clandestine combat from childhood, the Jinyiwei were masters of the 14 Blades; eight being for torture, five for killing, and the last blade reserved for suicide when a mission failed. An elite force of secret agents with a license to kill, the Jinyiwei devoted their lives and lethal prowess to the service of the Emperor alone. When the Imperial Court is taken over by evil eunuch Jia (Law Kar Ying), the best of the Jinyiwei, Qinglong (Donnie Yen) is assigned to steal a list identifying those still loyal to the Emperor. However unbeknownst to Qinglong, the Jinyiwei have fallen under the control of Jia, and during the mission Qinglong is betrayed and barely escapes with his life. Now as the most wanted man in the land, Qinglong must seek out and rally the loyalists to rise against Jia and restore the Emperor to power. In his way are the deadliest assassins in the land, his former brethren, the Jinyiwei.',
#   'release_date': '2010-02-04'},
#  {'vote_count': 3,
#   'id': 64990,
#   'video': False,
#   'vote_average': 6,
#   'title': 'Heaven Sword and Dragon Sabre II',
#   'popularity': 2.388,
#   'poster_path': '/c6WV40xH9ZkfqbqvHA59pyji6I.jpg',
#   'original_language': 'en',
#   'original_title': 'Yi tian tu long ji da jie ju',
#   'genre_ids': [28, 18, 14],
#   'backdrop_path': '/b2MJzKTSmjByJ3jXVjSEnDRDGCu.jpg',
#   'adult': False,
#   'overview': 'The thrills continue in this second part of this cherished adventure, created by the renowned director Chu Yuan and ingenious novelist Chin Yung. Only the union of the title weapons can save the six remaining martial arts sects who are vying for mastery. So just sit back and enjoy the movie event which spawned a legacy that continues even today with a long-running, internationally loved television series, a role-playing game, and even collectible replicas of the Heaven Sword and Dragon Sabre themselves!',
#   'release_date': '1978-10-27'},
#  {'vote_count': 1,
#   'id': 465992,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Guo Ming Yi',
#   'popularity': 0.625,
#   'poster_path': '/v1RDIUi16BDpj27FZx5pIVzaSRq.jpg',
#   'original_language': 'zh',
#   'original_title': '郭明义',
#   'genre_ids': [18],
#   'backdrop_path': '/wfrqAhXoEJQM4TEubOv5G36UZt8.jpg',
#   'adult': False,
#   'overview': 'In 2011, a movie biography of Guo Mingyi was Produced. The movie was directed by Chen Guoxing and Wang Jing, with the lead part played by Hou Yong and supporting parts by Jiang Hongbo, Li Qin and Feng.',
#   'release_date': '2011-07-15'},
#  {'vote_count': 2,
#   'id': 129171,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Fox Ghost',
#   'popularity': 2.184,
#   'poster_path': '/xEoGh1IL3AGrrqoAhcjuYgHbX3D.jpg',
#   'original_language': 'cn',
#   'original_title': 'Liao zhai zhi yi: Nie yu gu gui',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'To is a "diamond"--a handsome, outstanding student and always wins women\'s hearts. He is honored by tycoon Keung and soon married his daughter. To prepare for the upcoming exam, To moves in an abandoned house. During his stay, he meets two sexy, beautiful, and troublesome ghosts. However, he manages to tame them and falls in love with them. While he is on the way to the exam, he gets dragged in a dangerous situation. To asks the two ghosts for help...',
#   'release_date': '2002-01-01'},
#  {'vote_count': 38,
#   'id': 24922,
#   'video': False,
#   'vote_average': 6.4,
#   'title': 'Ebola Syndrome',
#   'popularity': 3.735,
#   'poster_path': '/slWmF08D96weToG2LkCbP5HSH3Z.jpg',
#   'original_language': 'cn',
#   'original_title': '伊波拉病毒',
#   'genre_ids': [27, 80, 35],
#   'backdrop_path': '/vqVmagaI2eNiPHE3woyzJAHFiD8.jpg',
#   'adult': False,
#   'overview': 'A restaurant employee wanted for murder contracts Ebola by raping a woman in South Africa and starts an outbreak there and in Hong Kong when he returns home.',
#   'release_date': '1996-06-15'},
#  {'vote_count': 0,
#   'id': 415107,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Hwang Jin Yi',
#   'popularity': 0.6,
#   'poster_path': '/sZMoJPUhuezhZFaVbfDidYHyI4z.jpg',
#   'original_language': 'ko',
#   'original_title': '황진이',
#   'genre_ids': [10749, 18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Magistrate Hwang's daughter Jin-yi, is jilted before her wedding because a shoe maker was smitten with her and commits suicide. Jin-yi becomes a courtesan, and becomes famous for her wits and beauty. She falls for Byuk Kye-su, but he's chosen to be an envoy to a far off kingdom. When he leaves she feels so betrayed she takes to a life of wandering. She meets Lee Saeng, a destitute scholar, and stays with him until she discovers he's going to sell her to a group of itinerate clowns. Instead, she joins them willingly.",
#   'release_date': '1986-09-18'},
#  {'vote_count': 3,
#   'id': 40896,
#   'video': False,
#   'vote_average': 7.3,
#   'title': 'Chicken Poets',
#   'popularity': 1.429,
#   'poster_path': '/ciFRyhSsZwo8vfDKkQ5tqf7SdlO.jpg',
#   'original_language': 'zh',
#   'original_title': 'Xiang ji mao yi yang fei',
#   'genre_ids': [18],
#   'backdrop_path': '/kA6gNhUIqGXl8VptF1xJf8AccIB.jpg',
#   'adult': False,
#   'overview': 'Yun Fei, a young poet, seeks the advice of an old university friend who lives in the Beijing suburbs, discovering that his friend has gone into business breeding black chickens. Discouraged about his future as a poet, Yun Fei starts a relationship with a colorblind young girl who encourages him to persevere. But even this new relationship is not enough to inspire him to write. It’s at this point that he buys a pirated record whose magical powers bring him the success he’s longed for. However, sudden fame does not seem to solve everything. The first film of Beijing theatre director Meng Jing Hui, Chicken Poets is an insightful and poetic look at materialism and the younger generation in China.',
#   'release_date': '2002-04-01'},
#  {'vote_count': 136,
#   'id': 14295,
#   'video': False,
#   'vote_average': 7,
#   'title': 'You Can Count on Me',
#   'popularity': 7.413,
#   'poster_path': '/7mGFmij1FZD5eUnNwvUjmpqrDl6.jpg',
#   'original_language': 'en',
#   'original_title': 'You Can Count on Me',
#   'genre_ids': [18, 10749],
#   'backdrop_path': '/hardcwpNmv4soWzTZWWD6OhzsSX.jpg',
#   'adult': False,
#   'overview': "A single mother's life is thrown into turmoil after her struggling, rarely-seen younger brother returns to town.",
#   'release_date': '2000-11-17'},
#  {'vote_count': 7520,
#   'id': 77,
#   'video': False,
#   'vote_average': 8.2,
#   'title': 'Memento',
#   'popularity': 14.229,
#   'poster_path': '/fQMSaP88cf1nz4qwuNEEFtazuDM.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento',
#   'genre_ids': [9648, 53],
#   'backdrop_path': '/puuwLLytKjZuv73SFqBihd6X5ES.jpg',
#   'adult': False,
#   'overview': "Leonard Shelby is tracking down the man who raped and murdered his wife. The difficulty of locating his wife's killer, however, is compounded by the fact that he suffers from a rare, untreatable form of short-term memory loss. Although he can recall details of life before his accident, Leonard cannot remember what happened fifteen minutes ago, where he's going, or why.",
#   'release_date': '2000-10-11'},
#  {'vote_count': 4,
#   'id': 517931,
#   'video': False,
#   'vote_average': 7,
#   'title': 'Memento Mori',
#   'popularity': 1.653,
#   'poster_path': '/mKxltWnGWOdPrvjzAX47WgDOAMN.jpg',
#   'original_language': 'nl',
#   'original_title': 'Memento Mori',
#   'genre_ids': [27, 9648],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Memento Mori is about a girl who's stuck in a dream circle, reliving key moments of a traumatic event. What happened to her? And will she survive this nightmare before time runs out?",
#   'release_date': '2018-04-07'},
#  {'vote_count': 43,
#   'id': 54111,
#   'video': False,
#   'vote_average': 6.2,
#   'title': 'Memento Mori',
#   'popularity': 3.682,
#   'poster_path': '/zpszvqERMuVL7iUCnKGn9Trwnxr.jpg',
#   'original_language': 'ko',
#   'original_title': '여고괴담 두번째 이야기',
#   'genre_ids': [14, 27, 10749],
#   'backdrop_path': '/7cB8R7s1V7oXUniKxn20sshm6hZ.jpg',
#   'adult': False,
#   'overview': 'In this second installment of the Whispering Corridors series, a young girl finds a strange diary, capable of arousing hallucinations, kept by two of her senior fellow-students who seem to have an unusually close bond.',
#   'release_date': '1999-12-24'},
#  {'vote_count': 1,
#   'id': 348128,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': '/nD8ZwEEmSPoLckTFABNJd1Kf11T.jpg',
#   'original_language': 'mk',
#   'original_title': 'Memento',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A day before the earthquake in Skopje, Wily Muller, a German conductor, while passing through the concert meets a young girl Jana, a student from Skopje. After several years they meet again at the "Solidarity Meetings" event, which is held in Skopje, where Wily Muller is a conductor at a concert held on that occasion. Those several days, spent together with the conductor, for Jana mean fulfillment with a kind of reminiscence of her family tragedy experienced during Skopje\'s earthquake, and also a wondering and search for a way of starting life again, which stopped on the day of the earthquake. Although the possibility of going with Muller is very attractive, Jana stays in Skopje. Her place is beside the young man whom she loves and belongs to, with whom she is related with true love...',
#   'release_date': '1967-01-01'},
#  {'vote_count': 0,
#   'id': 346610,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': '/rkJh7yKAFpv884kydTeiJ38zfh.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Experimental short film about car wreckage and automobile safety.',
#   'release_date': '1968-12-31'},
#  {'vote_count': 0,
#   'id': 438742,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': '/fHgIyoLAFyMmHwuEOXz7LpRLqoi.jpg',
#   'original_language': 'de',
#   'original_title': 'Memento',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A film about Jewish cemeteries in East Berlin, based on a screenplay by Günter Kunert, with text by Rabbi Martin Riesenburger. There are shots of gravestones and inscriptions – deported, murdered, perished; in Auschwitz or Theresienstadt. Commentary reminds us of the victims – "in 1933, 160,564 Jewish citizens lived in Berlin; in 1945, 3,500".',
#   'release_date': '1966-02-16'},
#  {'vote_count': 2,
#   'id': 383069,
#   'video': False,
#   'vote_average': 7,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': '/x41LeaHq7LlK4Y2yOZLTzP8UTTE.jpg',
#   'original_language': 'cn',
#   'original_title': 'Memento',
#   'genre_ids': [53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A cop, a blind psychologist, and a mysterious murderer are embroiled in a mental game copying thriller movies. As the suspects are being killed one after another, the case seems to be heading to a dead end. When the answer seems to be knocking at the door, as the murderer finally is exposed and killed, the unexpected is standing right in front of them...',
#   'release_date': '2002-11-28'},
#  {'vote_count': 0,
#   'id': 417615,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Memento',
#   'genre_ids': [9648, 53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A remake of the 2000 film, 'Memento', which centers on a man suffering from short-term memory loss while trying to track down his wife's killer.",
#   'release_date': ''},
#  {'vote_count': 0,
#   'id': 541025,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mori',
#   'popularity': 0.904,
#   'poster_path': '/m1Ma5aOtUi3Zp8zucTbnSKJ6fd3.jpg',
#   'original_language': 'ko',
#   'original_title': '메멘토모리',
#   'genre_ids': [53],
#   'backdrop_path': '/7yhAGnyvMs0jx6iPmi11Oa3rXyu.jpg',
#   'adult': False,
#   'overview': 'Suddenly they woke up. Not knowing who did it, 6 of them got up in the same place. The survival game for 6 people with nothing in common has begun.',
#   'release_date': '2018-06-28'},
#  {'vote_count': 1,
#   'id': 504521,
#   'video': False,
#   'vote_average': 5,
#   'title': "Zadar's Memento",
#   'popularity': 0.6,
#   'poster_path': '/bOEUJTbFUeDX4GfjoEL5xoX2KAv.jpg',
#   'original_language': 'hr',
#   'original_title': 'Zadarski memento',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The painful challenges experienced in the life of a farmer from Zadar, Croatia, in the years from World War I to World War II.',
#   'release_date': '1984-05-20'},
#  {'vote_count': 0,
#   'id': 381742,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento mori',
#   'popularity': 0.6,
#   'poster_path': '/vE2tAsXHBlWf2I60BCc7QQ0RF4l.jpg',
#   'original_language': 'ru',
#   'original_title': 'Мементо мори',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '1991-02-08'},
#  {'vote_count': 0,
#   'id': 374795,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mortis',
#   'popularity': 0.603,
#   'poster_path': '/cYeAwK4ZoxYNtRcKJywQiEyaK3W.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento Mortis',
#   'genre_ids': [27],
#   'backdrop_path': '/ajVOcKxdCcyGOaEW3vJB23vCNin.jpg',
#   'adult': False,
#   'overview': 'A photographer uses dead bodies as props in her erotic photos. Everything was going well until she fell in love.',
#   'release_date': '2015-11-20'},
#  {'vote_count': 1,
#   'id': 208728,
#   'video': False,
#   'vote_average': 7,
#   'title': 'memento mori',
#   'popularity': 0.6,
#   'poster_path': '/dGeseHgEFd8AWZW5wepPkCTEQ7Q.jpg',
#   'original_language': 'en',
#   'original_title': 'memento mori',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'memento mori is a layered exploration of the total photographs captured over the course of a lifetime – over 100,000 in total. This personal archive, the dizzying documentation of a life, represents a plurality of subjects, objects, thoughts, dreams and experiences, forming an encyclopedic index of the possibilities of sight.',
#   'release_date': '2012-09-19'},
#  {'vote_count': 1,
#   'id': 430775,
#   'video': False,
#   'vote_average': 6,
#   'title': 'Memento Mori',
#   'popularity': 0.6,
#   'poster_path': '/3LR3aiNct2wDNPnkXFlhnriwl0q.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento Mori',
#   'genre_ids': [9648, 35],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "After an accident, Daming can't remember what happened last night. Back home, he discovers in his closet the dead body of Gao Yan. Who killed this man hated by so many people included Daming himself?",
#   'release_date': '2016-06-03'},
#  {'vote_count': 0,
#   'id': 271038,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mori',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Memento Mori',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Viewed from the world of Roger Ballen. Ballen is renowned for his confronting and bleak black and white portraits of marginalised South Africans. Melle van Essen follows in Ballen’s footsteps by creating 'Living' photographs with fixed frames and strong black and white contrasts with great emphasis on composition.",
#   'release_date': '2005-09-01'},
#  {'vote_count': 0,
#   'id': 384914,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mori',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'de',
#   'original_title': 'Memento Mori',
#   'genre_ids': [9648, 18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The writer Charmain Colson entertains a circle of old friends. One day, when the group receive an anonymous message saying Memento Mori/Remember you must die, they all panic in fear and angst.',
#   'release_date': '1975-01-05'},
#  {'vote_count': 0,
#   'id': 518808,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mori',
#   'popularity': 0.6,
#   'poster_path': '/gxNzkGB9PrNmnF7BwKEwRIcAg2K.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento Mori',
#   'genre_ids': [18, 28],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': ''},
#  {'vote_count': 0,
#   'id': 575852,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Stella',
#   'popularity': 0.6,
#   'poster_path': '/bjDZJrExq0ILGnfHgAt3S3bXBE0.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento Stella',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Makino Takashi takes us to a place where different rules apply. He overwhelms us with his universe, which is built up of countless images, figurative and non-figurative, accompanied by an equally sophisticated soundtrack. At times very abstract and distant, at others almost palpable and narrative. We naturally seek recognition in the infinite layering of the images, and in so doing compose our own story, based on what we ourselves know of the world, using our personal references to help us. In this way, a work arises unique to every viewer, which continues to reverberate long after we leave the cinema.',
#   'release_date': '2019-01-26'},
#  {'vote_count': 0,
#   'id': 369827,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento mori',
#   'popularity': 0.6,
#   'poster_path': '/nRNRH27eY6gLBRWDQfLMHMzwAlg.jpg',
#   'original_language': 'ru',
#   'original_title': 'Memento mori',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '1996-01-01'},
#  {'vote_count': 0,
#   'id': 466084,
#   'video': True,
#   'vote_average': 0,
#   'title': 'Memento - A Boulder Life Line',
#   'popularity': 0.6,
#   'poster_path': '/8KUZbcxszWWYFldTwEX3ArwQvCD.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento - A Boulder Life Line',
#   'genre_ids': [28, 12, 99],
#   'backdrop_path': '/gt9LrJa6GfWZcjv4nE1NhR6zuDg.jpg',
#   'adult': False,
#   'overview': 'What happens when a crazy filmmaker meets a crazy boulder and they decide to make a film together? It could be called pre-programmed chaos or the beginning of a common vision. After nearly two years of work, the film is finished, pure soul has come out! Camera and direction show boulders in a unique style. The philsophy and climbing art of Bernd Zangerl set the crown on the film. The locations were Ticino, Magic Wood and the mountains of the Silvretta. Each area has its own character, its own style and ambience. \'Every centimeter has its meaning. As with Humbold\'s natural vision, thought and feeling merge, and here the symbiosis of man and rock, man\'s stone, humanized petrified. "  The film shows Bernd Zangerl, Barbara Zangerl and Thomas "Steini" Steinbrugger during bouldering at Magic Wood, Silvretta and Ticino. The best and most beautiful first visits by Bernd Zangerl are documented as well as spectacular highballs and low water soloing.',
#   'release_date': '2006-01-01'},
#  {'vote_count': 249,
#   'id': 13785,
#   'video': False,
#   'vote_average': 7.1,
#   'title': 'Best in Show',
#   'popularity': 7.822,
#   'poster_path': '/rDoVUVT5CGkraBjEukfBTHsxBN9.jpg',
#   'original_language': 'en',
#   'original_title': 'Best in Show',
#   'genre_ids': [35],
#   'backdrop_path': '/ed8CWIUFrjFYEcJP1C8uc3wEcNM.jpg',
#   'adult': False,
#   'overview': 'The tension is palpable, the excitement is mounting and the heady scent of competition is in the air as hundreds of eager contestants from across America prepare to take part in what is undoubtedly one of the greatest events of their lives -- the Mayflower Dog Show. The canine contestants and their owners are as wondrously diverse as the great country that has bred them.',
#   'release_date': '2000-09-19'},
#  {'vote_count': 0,
#   'id': 352510,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Fantasia in Best Show Minor',
#   'popularity': 0.6,
#   'poster_path': '/emLJJTg26z084sKNSAZBO5hCzqq.jpg',
#   'original_language': 'en',
#   'original_title': 'Fantasia in Best Show Minor',
#   'genre_ids': [35],
#   'backdrop_path': '/oOJ4kVrJgFv0F0mKDGEgNIrYafG.jpg',
#   'adult': False,
#   'overview': 'Fantasia in Best Show Minor is the first and only ever Best Show on WFMU DVD Release! It features stuff you’re never going to believe, puppets. animation, sketches, travelogues from callers, and guest appearances from Patton Oswalt, Ted Leo, Paul F. Tompkins, Zach Galifinakis, Fucked Up, Tim and Eric, John Hodgeman, Aimee Mann, Scharpling and Wurster, Yo La Tengo, Kurt Vile, Matt Fracton, Todd Barry, and Jason Woliner. The DVD was available exclusively during the 2010 WFMU pledge drive.',
#   'release_date': '2010-01-01'},
#  {'vote_count': 0,
#   'id': 338169,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Strawberry Shortcake: Berry Best in Show',
#   'popularity': 0.6,
#   'poster_path': '/gwfkWB5BL2cYUpAuxs999n17MBK.jpg',
#   'original_language': 'en',
#   'original_title': 'Strawberry Shortcake: Berry Best in Show',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Strawberry Shortcake and her pals meet some new furry friends in these delightful "tails" about being yourself and encouraging others to do the same. Strawberry helps out some stray pooches in "A Boy and His Dogs." Blueberry Muffin and Huck become "Partners in Crime" when they try to write a mystery story. And the girls start a dog shelter in "The Mystery of the Disappearing Dog Show."',
#   'release_date': '2015-04-28'},
#  {'vote_count': 964,
#   'id': 1900,
#   'video': False,
#   'vote_average': 7,
#   'title': 'Traffic',
#   'popularity': 14.877,
#   'poster_path': '/9qPLd5hdXIlrAyknVWK38eZyUMo.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic',
#   'genre_ids': [53, 18, 80],
#   'backdrop_path': '/ivAC8eZkzKoTf8EWQh7pkFD0AGS.jpg',
#   'adult': False,
#   'overview': "An exploration of the United States of America's war on drugs from multiple perspectives. For the new head of the Office of National Drug Control Policy, the war becomes personal when he discovers his well-educated daughter is abusing cocaine within their comfortable suburban home. In Mexico, a flawed, but noble policeman agrees to testify against a powerful general in league with a cartel, and in San Diego, a drug kingpin's sheltered trophy wife must learn her husband's ruthless business after he is arrested, endangering her luxurious lifestyle.",
#   'release_date': '2000-12-27'},
#  {'vote_count': 14,
#   'id': 142948,
#   'video': False,
#   'vote_average': 7.5,
#   'title': 'Traffic',
#   'popularity': 1.896,
#   'poster_path': '/3ficNeBPB03vUZ9N7okWftKpyr9.jpg',
#   'original_language': 'ml',
#   'original_title': 'ട്രാഫിക്',
#   'genre_ids': [53],
#   'backdrop_path': '/tx0KFYxQ9atSOSflbnJzaIGEGlm.jpg',
#   'adult': False,
#   'overview': 'An emotional thriller based on a road trip from Kochi to Palakkad. Inspired from the real events that happened in Chennai.',
#   'release_date': '2011-01-07'},
#  {'vote_count': 153,
#   'id': 11129,
#   'video': False,
#   'vote_average': 6.8,
#   'title': 'Human Traffic',
#   'popularity': 7.067,
#   'poster_path': '/4FmaeS2uBVhpjnFuGphV5lAKXZ7.jpg',
#   'original_language': 'en',
#   'original_title': 'Human Traffic',
#   'genre_ids': [35, 18],
#   'backdrop_path': '/zGjyVVWkqF8ywo49ISp3bBhWmPo.jpg',
#   'adult': False,
#   'overview': 'Five twenty-something friends spend a drug-fueled weekend in Cardiff, Wales.',
#   'release_date': '1999-06-04'},
#  {'vote_count': 2,
#   'id': 504195,
#   'video': False,
#   'vote_average': 4,
#   'title': 'Traffic Ramasamy',
#   'popularity': 1.785,
#   'poster_path': '/q1SvwdOxC3OhZii5pagDTJGsU6V.jpg',
#   'original_language': 'ta',
#   'original_title': 'டிராஃபிக் ராமசாமி',
#   'genre_ids': [18],
#   'backdrop_path': '/5qCkEMX7taLJaGEXv5BSdC1r73r.jpg',
#   'adult': False,
#   'overview': 'Social activist Traffic Ramasamy takes on the corrupt and powerful in his quest for justice. Can he succeed to bring them down, especially when they are keen to finish him off for good?',
#   'release_date': '2018-06-22'},
#  {'vote_count': 30,
#   'id': 30593,
#   'video': False,
#   'vote_average': 6.9,
#   'title': 'Heavy Traffic',
#   'popularity': 1.857,
#   'poster_path': '/A9jsB1t49L0p0mD7Wqn9Y4WVFkh.jpg',
#   'original_language': 'en',
#   'original_title': 'Heavy Traffic',
#   'genre_ids': [16, 35, 18],
#   'backdrop_path': '/458a7UKoPEN9HvNEwtLhqyPSoXj.jpg',
#   'adult': False,
#   'overview': 'An "underground" cartoonist contends with life in the inner city, where various unsavory characters serve as inspiration for his artwork.',
#   'release_date': '1973-08-08'},
#  {'vote_count': 61,
#   'id': 60046,
#   'video': False,
#   'vote_average': 7.7,
#   'title': 'The Traffic Policeman',
#   'popularity': 3.745,
#   'poster_path': '/o4zNFZ698gjr4D1ZaxNp0t7kPuM.jpg',
#   'original_language': 'it',
#   'original_title': 'Il vigile',
#   'genre_ids': [35],
#   'backdrop_path': '/vXducRNWdj4mcj3ssuXmvrh4pjz.jpg',
#   'adult': False,
#   'overview': 'An unemployed man gets a job as traffic policeman but the traffic in the big city creates innumerous problems for the poor guy.',
#   'release_date': '1960-01-01'},
#  {'vote_count': 7,
#   'id': 162285,
#   'video': False,
#   'vote_average': 6.1,
#   'title': 'Traffic Troubles',
#   'popularity': 1.437,
#   'poster_path': '/4fKAbYu40B0YmXqpsw8JAoJKwEx.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic Troubles',
#   'genre_ids': [16],
#   'backdrop_path': '/hdC7IfRCfIlMdFGwiyOjybWyxPo.jpg',
#   'adult': False,
#   'overview': 'Mickey is driving a taxi. His first fare is a very large gentleman. Mickey stops traffic and gets a tongue-lashing from the officer. The cab runs into some bad road, bounces the fare down to almost nothing, then bounces the customer right out of the cab. Mickey pulls up to the curb and picks up his second passenger, Minnie. She plays her accordion while they ride. The cab gets a flat tire, and Mickey uses a pig to pump it up.',
#   'release_date': '1931-03-16'},
#  {'vote_count': 14,
#   'id': 491206,
#   'video': False,
#   'vote_average': 6.2,
#   'title': 'Traffic Stop',
#   'popularity': 1.414,
#   'poster_path': '/kRVMLMn7uSyTrkg565j16kW6NgS.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic Stop',
#   'genre_ids': [99],
#   'backdrop_path': '/aJBXzOMnSOGX7T7SpUvMXIcByjm.jpg',
#   'adult': False,
#   'overview': 'Breaion King, a 26 year-old African-American school teacher from Austin, Texas,- is pulled over for a routine traffic stop that escalates into a violent arrest. Dashcam clips intercut with verite scenes tell a story of racism in law enforcement through the eyes of one of its victims.',
#   'release_date': '2017-11-14'},
#  {'vote_count': 2,
#   'id': 175240,
#   'video': False,
#   'vote_average': 7.5,
#   'title': 'Point Doom',
#   'popularity': 1.472,
#   'poster_path': '/pXRiIxYCeaw3LwRhsERJqgfjKq1.jpg',
#   'original_language': 'en',
#   'original_title': 'Point Doom',
#   'genre_ids': [28, 53, 80],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A Hollywood talent agent's girlfriend thrusts him into a world of strip clubs, drugs and deadly motorcycle gangs.",
#   'release_date': '2000-06-08'},
#  {'vote_count': 0,
#   'id': 463156,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Traffic',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Traffic',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Traffic 2014 Telugu Movie',
#   'release_date': ''},
#  {'vote_count': 0,
#   'id': 490165,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Traffic',
#   'popularity': 0.6,
#   'poster_path': '/cDH417FT8UhHGPmMWQD5r69d3Nz.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Pursuing a visual search regarding a reference that is common to other works, this audiovisual essay highlights the affinity between nature and labor. We are now able to see the ancestral tension between the organic and the artificial poetically dwell in the static shot, where the choreography of the birds, the rational metric of the constructors and the lapping of the water in the background coexist.',
#   'release_date': '2015-01-01'},
#  {'vote_count': 1,
#   'id': 480884,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Traffic',
#   'popularity': 0.6,
#   'poster_path': '/hpKwseS35j4SeZ8BGkhkKV5scbt.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The real truth behind the child protection system. Social workers, Judges, Lawyers and Guardians of the court all working together to secure the removal of children from their families and traffic them around the UK.',
#   'release_date': '2014-11-30'},
#  {'vote_count': 4,
#   'id': 128856,
#   'video': False,
#   'vote_average': 4.5,
#   'title': 'Traffic Affairs',
#   'popularity': 1.056,
#   'poster_path': '/gn52TI8EB6OoZB27RsWwqBquvWj.jpg',
#   'original_language': 'de',
#   'original_title': 'Mitfahrer – Jede Begegnung ist eine Chance',
#   'genre_ids': [18, 28, 53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '2004-02-06'},
#  {'vote_count': 34,
#   'id': 16464,
#   'video': False,
#   'vote_average': 5.9,
#   'title': 'Traffic Crossing Leeds Bridge',
#   'popularity': 1.473,
#   'poster_path': '/tI7SfgAWbNLtby4whM9MxVve4IA.jpg',
#   'original_language': 'xx',
#   'original_title': 'Traffic Crossing Leeds Bridge',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A film by Louis Aimé Augustin Le Prince, shot in late October 1888, showing pedestrians and carriages crossing Leeds Bridge.',
#   'release_date': '1888-10-15'},
#  {'vote_count': 3,
#   'id': 191098,
#   'video': False,
#   'vote_average': 7.7,
#   'title': 'Traffic Officer',
#   'popularity': 1.4,
#   'poster_path': '/1g21kSoGm9OUP0ZEidTfbAGhQj8.jpg',
#   'original_language': 'ru',
#   'original_title': 'Inspektor GAI',
#   'genre_ids': [35, 18],
#   'backdrop_path': '/bskX5Y4xGMnkdQ06CRfxSHje4jN.jpg',
#   'adult': False,
#   'overview': 'A comic drama about a permanently going duel between Traffic Officer and powerful businessman.',
#   'release_date': '1982-06-06'},
#  {'vote_count': 3,
#   'id': 54917,
#   'video': False,
#   'vote_average': 7.3,
#   'title': 'Traffic Warden',
#   'popularity': 0.937,
#   'poster_path': '/xTfqDq9JRYJrYDuwOr5XalyGrxT.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic Warden',
#   'genre_ids': [35],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A comic short – in fact, a bite-size romantic comedy – in which a serendipitous series of events leads a traffic warden (played by David Tennant) to find true love.',
#   'release_date': '2005-01-01'},
#  {'vote_count': 25,
#   'id': 167179,
#   'video': False,
#   'vote_average': 6.9,
#   'title': 'Traffic Department',
#   'popularity': 2.358,
#   'poster_path': '/5iDhJc9NfOI3IMnmzAL8TJe3fNu.jpg',
#   'original_language': 'pl',
#   'original_title': 'Drogówka',
#   'genre_ids': [18, 80],
#   'backdrop_path': '/1lJfWBTiOTDkv2ThBtKhDfLP7sq.jpg',
#   'adult': False,
#   'overview': 'Seven policemen, seven deadly sins, a murder case, secrets and the filth of everyday police work: Traffic Department transports the viewer into the darkest Warsaw streets.',
#   'release_date': '2013-01-31'},
#  {'vote_count': 3,
#   'id': 46426,
#   'video': False,
#   'vote_average': 6.7,
#   'title': 'Traffic Signal',
#   'popularity': 0.953,
#   'poster_path': '/r5fwik43w0BG1pKTgvSuySwtToN.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic Signal',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Silsila is the "manager" of one traffic signal, that is he collects the "hafta" (protection tax) from each signal squatter plying his trade. There\'s Tsunami, a little scavenger boy, there\'s Rani - a Gujrati girl selling ethnic clothes on the sidewalk, and there\'s Dominic - a drug addict and the prostitute who feels for him...',
#   'release_date': '2007-02-07'},
#  {'vote_count': 4,
#   'id': 50118,
#   'video': False,
#   'vote_average': 5.8,
#   'title': 'Traffic',
#   'popularity': 0.775,
#   'poster_path': '/2RJCCdENmWfsujdmbzafdVACRw9.jpg',
#   'original_language': 'pt',
#   'original_title': 'Tráfico',
#   'genre_ids': [35],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Young Jesus (Joaquim Oliviera) is taken on a vacation by his parents (Rita Blanco, Adriano Luz) to a deserted beach resort. They accidentally fall into overnight wealth after Jesus digs in the sand, uncovering a large drug stash. Others characters intersecting here include an alcoholic actress, a philandering banker, a general trafficking in arms, priests who close their church and head north as hitchhikers, politicians who watch an all-girl production of Julius Caesar, and beggars who recite a children's story in a huge heap of trash.",
#   'release_date': '1998-12-31'},
#  {'vote_count': 1,
#   'id': 214397,
#   'video': False,
#   'vote_average': 3,
#   'title': 'Girls in the Night Traffic',
#   'popularity': 1.627,
#   'poster_path': '/pSg53acAsE4EMv942GrjQR5dSSw.jpg',
#   'original_language': 'de',
#   'original_title': 'Mädchen im Nachtverkehr',
#   'genre_ids': [18, 35],
#   'backdrop_path': '/hK35I08sEzrMMTA97HqNI8QA0hp.jpg',
#   'adult': False,
#   'overview': 'Three prostitutes living together in a large apartment and tells stories about their quirky cods. Then tricked into white slavery by the murky Turk Mustafa and taken to a harem in the Middle East! They use their cunning and seduction skills to try to escape.',
#   'release_date': '1976-07-13'},
#  {'vote_count': 109,
#   'id': 12706,
#   'video': False,
#   'vote_average': 6.9,
#   'title': 'Croupier',
#   'popularity': 4.482,
#   'poster_path': '/s8wDHdBDGiBuVeQDP9mdm9u3b9U.jpg',
#   'original_language': 'en',
#   'original_title': 'Croupier',
#   'genre_ids': [18, 53],
#   'backdrop_path': '/obZPzdJ3SmfGnoXtzMc58w5QjIx.jpg',
#   'adult': False,
# ...
#   'release_date': '2017-05-03'},
#  {'vote_count': 0,
#   'id': 261473,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Million Dollars Snatch',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Qi bai wan yuan da jie an',
#   'genre_ids': [28, 80, 35],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "The grandson of a petroleum company president is kidnapped in Rome. The kidnappers want $10 million dollars in ransom money. The boy's grandfather wants his grandson back but doesn't want to pay, so he hires detectives to go after the boy. Three local detectives have a go at it, and fail with comedic humiliation. While lamenting their frustrations at a Chinese restaurant, they notice two young waiters playfully exchanging martial arts moves and instantly enlist the eldest to get the boy back before the kidnappers cut off his ear.",
#   'release_date': '1976-08-13'},
#  {'vote_count': 0,
#   'id': 358123,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatch of the Day',
#   'popularity': 0.6,
#   'poster_path': '/unamVX3vEezw5lifYybdp3cZv0B.jpg',
#   'original_language': 'en',
#   'original_title': 'Snatch of the Day',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Part of BFI collection "Police and Thieves."',
#   'release_date': '1975-01-02'},
#  {'vote_count': 0,
#   'id': 274882,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatch N Grab',
#   'popularity': 0.6,
#   'poster_path': '/7KBxC7pCOTPQZ6Ct41OfvVwLQKa.jpg',
#   'original_language': 'en',
#   'original_title': 'Snatch N Grab',
#   'genre_ids': [35, 10749],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Tired of being treated poorly by men, four frustrated women devise a game of social conquest to reclaim their destinies. But each is soon challenged to face herself and her relationships while also battling a jealous psycho and sexist boss.',
#   'release_date': '2010-01-01'},
#  {'vote_count': 147,
#   'id': 4722,
#   'video': False,
#   'vote_average': 5.9,
#   'title': 'Body Snatchers',
#   'popularity': 8.489,
#   'poster_path': '/4GLnErLrLfban9JDCOsxB9Xeegq.jpg',
#   'original_language': 'en',
#   'original_title': 'Body Snatchers',
#   'genre_ids': [27, 878, 53],
#   'backdrop_path': '/8rjgIzDtLKucvg2u5zzFCyDFAnb.jpg',
#   'adult': False,
#   'overview': "When Environmental Protection Agency inspector Steve Malone travels to a remote military base in order to check for toxic materials, he brings his family along for the ride. After arriving at the base, his teenage daughter Marti befriends Jean Platt, daughter of the base's commander, General Platt. When people at the base begin acting strangely, Marti becomes convinced that they are slowly being replaced by plant-like aliens.",
#   'release_date': '1993-06-09'},
#  {'vote_count': 396,
#   'id': 11549,
#   'video': False,
#   'vote_average': 7.5,
#   'title': 'Invasion of the Body Snatchers',
#   'popularity': 15.884,
#   'poster_path': '/4oj0G2Zr6tQKBDOzKaLuefdeBsG.jpg',
#   'original_language': 'en',
#   'original_title': 'Invasion of the Body Snatchers',
#   'genre_ids': [27, 878],
#   'backdrop_path': '/eTxgy8eROB5Ly7ZXKLukQoF6tKl.jpg',
#   'adult': False,
#   'overview': 'A small-town doctor learns that the population of his community is being replaced by emotionless alien duplicates.',
#   'release_date': '1956-02-05'},
#  {'vote_count': 0,
#   'id': 580632,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatchers',
#   'popularity': 1.264,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Snatchers',
#   'genre_ids': [27, 878],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Sara’s one of the cool kids... but she’s totally terrified of losing her status. She’d be a lot more secure if she could just win back her super-hot ex, Skyler, but he’s not interested unless they move to the next level...  She decides to take the plunge -- but something about Skyler changed on his summer trip to Mexico... something in his nards.  Sara wakes the next morning only to find that she’s nine-months pregnant. Desperate to keep this under wraps, she turns to the only person she can trust: her nerdy ex-best friend, Hayley.  But after a trip to the clinic results in Sara birthing something other-worldly, the girls realize their night is only just getting started...',
#   'release_date': '2019-03-10'},
#  {'vote_count': 374,
#   'id': 11850,
#   'video': False,
#   'vote_average': 7.3,
#   'title': 'Invasion of the Body Snatchers',
#   'popularity': 7.973,
#   'poster_path': '/skS02wdeH2C0nrbCQP3qKwJdZtZ.jpg',
#   'original_language': 'en',
#   'original_title': 'Invasion of the Body Snatchers',
#   'genre_ids': [27, 9648, 878, 53],
#   'backdrop_path': '/gnVXP708WiJAH6oMhdSRAik4XTl.jpg',
#   'adult': False,
#   'overview': 'The first remake of the paranoid infiltration classic moves the setting for the invasion, from a small town to the city of San Francisco and starts as Matthew Bennell notices that several of his friends are complaining that their close relatives are in some way different. When questioned later they themselves seem changed, as they deny everything or make lame excuses. As the invaders increase in number they become more open and Bennell, who has by now witnessed an attempted "replacement", realises that he and his friends must escape or suffer the same fate. But who can he trust to help him and who has already been snatched?',
#   'release_date': '1978-12-19'},
#  {'vote_count': 64,
#   'id': 30346,
#   'video': False,
#   'vote_average': 7,
#   'title': 'The Body Snatcher',
#   'popularity': 3.894,
#   'poster_path': '/1dOCP2ahMVlA95SivxhEdVvcXZE.jpg',
#   'original_language': 'en',
#   'original_title': 'The Body Snatcher',
#   'genre_ids': [80, 27],
#   'backdrop_path': '/noIqfaKdX3go0GinBAfnnBnYTNh.jpg',
#   'adult': False,
#   'overview': 'Edinburgh, 1831. Among those who undertake the illegal trade of grave robbery is Gray, ostensibly a cab driver. Formerly a medical student convicted of grave robbery, Gray holds a grudge against Dr. MacFarlane who had escaped detection and punishment.',
#   'release_date': '1945-05-25'},
#  {'vote_count': 0,
#   'id': 378918,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatched',
#   'popularity': 0.883,
#   'poster_path': '/2gUnuiXoYTkRG63fp0cP9h9Qp4a.jpg',
#   'original_language': 'en',
#   'original_title': 'Snatched',
#   'genre_ids': [80, 18, 53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "The wives of three wealthy men are kidnapped and held for a $3 million ransom, but one of the men doesn't want to pay his share.",
#   'release_date': '1973-01-31'},
#  {'vote_count': 21,
#   'id': 22451,
#   'video': False,
#   'vote_average': 4.7,
#   'title': 'The Bone Snatcher',
#   'popularity': 3.284,
#   'poster_path': '/kceAJpK27zaE2IdXU1iIzUHZcIt.jpg',
#   'original_language': 'en',
#   'original_title': 'The Bone Snatcher',
#   'genre_ids': [878, 27],
#   'backdrop_path': '/9uDB03qgISKFvbR6IAQeHyxmukL.jpg',
#   'adult': False,
#   'overview': 'After miners disappear in the Namib Desert, some scientists find their remains and the demonic creature that killed them.',
#   'release_date': '2003-12-23'},
#  {'vote_count': 0,
#   'id': 531530,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatchers',
#   'popularity': 0.84,
#   'poster_path': '/5HVZkMsMLifuwsJxw59QQcHRhxL.jpg',
#   'original_language': 'en',
#   'original_title': 'Snatchers',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A teenager's trip to the clinic becomes freakier than usual when she learns that something otherworldly is involved.",
#   'release_date': '2016-03-11'},
#  {'vote_count': 535,
#   'id': 10866,
#   'video': False,
#   'vote_average': 6.4,
#   'title': 'Joy Ride',
#   'popularity': 7.784,
#   'poster_path': '/q8y2T2LvJV0mvia1RA9pS1K33GR.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride',
#   'genre_ids': [9648, 53, 18],
#   'backdrop_path': '/wr9KMaCGGquZQqmjN8mRqOR2FeM.jpg',
#   'adult': False,
#   'overview': 'Three young people on a road trip from Colorado to New Jersey talk to a trucker on their CB radio, then must escape when he turns out to be a psychotic killer.',
#   'release_date': '2001-10-05'},
#  {'vote_count': 96,
#   'id': 16763,
#   'video': False,
#   'vote_average': 5.4,
#   'title': 'Joy Ride 2: Dead Ahead',
#   'popularity': 6.661,
#   'poster_path': '/dYuz2lnKz3ZZY4CsWVGZanm6TMb.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride 2: Dead Ahead',
#   'genre_ids': [80, 53],
#   'backdrop_path': '/lslrLtCMyPgZYtjBR3LKCuG02wB.jpg',
#   'adult': False,
#   'overview': "While driving to Las Vegas for the bachelor party of her sister Melissa and her fiance Bobby, Kayla stops the car in the gas station to meet her date, Nik, a guy she met on the internet. Nik convinces her to take a secondary road under the protest of Bobby but the car breaks down. They find a house in the middle of nowhere and decide to take the car parked in the house's garage to the next city...",
#   'release_date': '2008-10-07'},
#  {'vote_count': 81,
#   'id': 259074,
#   'video': False,
#   'vote_average': 4.7,
#   'title': 'Joy Ride 3',
#   'popularity': 3.251,
#   'poster_path': '/qfZsy4gxrBDvIzoiT0HqFjQgobP.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride 3',
#   'genre_ids': [53],
#   'backdrop_path': '/6LhwAiSscN1ef4c2alt9pjr1au7.jpg',
#   'adult': False,
#   'overview': "Rusty Nail is back on the road again looking to punish injustice at every turn - and this time it's with a group of hotheaded street racers on their way to the Road Rally 1000. As they drive through a desolate shortcut on the way to the race, an encounter with Rusty turns sour and soon he is tracking, teasing and torturing them until the end of the road.",
#   'release_date': '2014-06-03'},
#  {'vote_count': 0,
#   'id': 392055,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.627,
#   'poster_path': '/nIBj2juc0L1gIvuCGOjTypMCoxs.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Two cousins invite their girlfriends on a joy-ride, but car trouble leads to catastrophe!',
#   'release_date': '1935-12-16'},
#  {'vote_count': 0,
#   'id': 377538,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.6,
#   'poster_path': '/eW7MyFEzTiU2Ho28mD29ZVlDFMX.jpg',
#   'original_language': 'de',
#   'original_title': 'Usfahrt',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The 4th installment of the Dogme 95 Movement.',
#   'release_date': '2000-11-16'},
#  {'vote_count': 0,
#   'id': 208233,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.6,
#   'poster_path': '/xwzH9vP9245Gq0dMvEgMYJNlxaB.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride',
#   'genre_ids': [80, 18],
#   'backdrop_path': '/kX6Mn8UJOaOOpPEW6YXBDst2pAQ.jpg',
#   'adult': False,
#   'overview': "Teenage story of a bad apple in a barrel evolving from a kid's desire to drive a new T-bird.",
#   'release_date': '1958-11-23'},
#  {'vote_count': 0,
#   'id': 281519,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Joy Ride',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Tony Smalls is a lawyer on the fast track, moving quickly away from his roots in Detroit's rough Joy Road neighborhood. He's forced to put his plans on hold when his sister Nia asks him to defend her fiance, a gang kingpin who is under arrest for a triple murder that he says he didn't commit. Tony feels the pressure of the case when the feds and a shadowy corporation get involved, along with a private investigator who seems to be working all sides. When Nia starts an investigation of her own into the murder, it not only brings her closer to the truth - it puts both herself and Tony in harm's way.",
#   'release_date': '2012-01-01'},
#  {'vote_count': 0,
#   'id': 561948,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.6,
#   'poster_path': '/sWk1EeMh63XYbYFmoi87x6xe90T.jpg',
#   'original_language': 'hi',
#   'original_title': 'Joy Ride',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A documentary about human-powered manual ferris wheel rides at Juhu beach in Mumbai.',
#   'release_date': '2007-01-01'},
#  {'vote_count': 6,
#   'id': 128056,
#   'video': False,
#   'vote_average': 4.8,
#   'title': 'Joy Ride: An Auto Theft',
#   'popularity': 0.833,
#   'poster_path': '/u4uFzEGzEG4ODciadtP5ERt4i9C.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride: An Auto Theft',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "In the summer of '76, after pinball and complaining lose their thrill, Val and Tim steal their friend Randal's car.  The boys pick up some girls, Kari and Vicki, and go for a ride up in the hills.  They intend to return the stolen car before Randal finishes baseball practice, but their adolescent hijinks spiral out of control.  The short film seems to be designed to make teenagers see that joyriding isn't just a bit of fun.",
#   'release_date': '1976-01-01'},
#  {'vote_count': 0,
#   'id': 313946,
#   'video': False,
#   'vote_average': 0,
#   'title': 'A Joy Ride',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'A Joy Ride',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A Joy Ride is a 1922 animated short subject made by Bray Productions. It is among the many films starring Judge Rummy, the character from Tad Dorgan's comic strips.",
#   'release_date': '1922-06-17'},
#  {'vote_count': 5,
#   'id': 37128,
#   'video': False,
#   'vote_average': 6.4,
#   'title': 'Jolly Fellows',
#   'popularity': 1.067,
#   'poster_path': '/id0tb1Sqhb9XfPj7CfQsaQqOVEo.jpg',
#   'original_language': 'ru',
#   'original_title': 'Весёлые ребята',
#   'genre_ids': [10402, 35],
#   'backdrop_path': '/j79D7lj4WlCq0UtYK3sHT4TwRm4.jpg',
#   'adult': False,
#   'overview': 'Merry Fellows was the first Soviet musical comedy. Set in Odessa and Moscow in the 1930\'s. Shepherd Kostya Potekhin (Utyosov) is mistaken for an international concert star. He falls in love with Anyuta (Orlova) and plays the "star" for her. In a cascade of comic musical numbers he becomes the leader of a Jazz-Band and gives a hilarious show at the Odessa Music Hall. Now he is destined to perform at the Bolshoi Theatre in Moscow.',
#   'release_date': '1934-12-09'},
#  {'vote_count': 2697,
#   'id': 2034,
#   'video': False,
#   'vote_average': 7.4,
#   'title': 'Training Day',
#   'popularity': 12.736,
#   'poster_path': '/sDT2biSB7wzBJdXq9o3ldr7VfvY.jpg',
#   'original_language': 'en',
#   'original_title': 'Training Day',
#   'genre_ids': [28, 80, 18, 53],
#   'backdrop_path': '/A1S9fBzc4Wepc6onnCd9eVR2FLp.jpg',
#   'adult': False,
#   'overview': "On his first day on the job as a narcotics officer, a rookie cop works with a rogue detective who isn't what he appears.",
#   'release_date': '2001-10-05'},
#  {'vote_count': 0,
#   'id': 86316,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Training Day',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Training Day',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'TRAINING DAY is a half hour educational, inspirational, hip and fun sports show revealing how top, famous athletes, transform themselves from an average to super human. Creator, Director and host Flo Vinger will spend a day and training with these top athletes.',
#   'release_date': '2010-07-01'},
#  {'vote_count': 0,
#   'id': 358530,
#   'video': False,
#   'vote_average': 0,
#   'title': "Taro's Early Training Days",
#   'popularity': 0.6,
#   'poster_path': '/vuFTmAzeU897UwnWzndm6EQYH3Q.jpg',
#   'original_language': 'ja',
#   'original_title': '日の丸太郎～武者修行の巻～',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The hero Taro attempts to rescue a kidnapped girl from a bandit. Short film from 1936.',
#   'release_date': '1936-09-06'},
#  ...]

# %%
# create empty dataframe with column labels from the dictionary keys
movies_all = pd.DataFrame(columns=results1[0].keys())

# %%
# checking types of data in results1 - it's a mixed list of floats and dictionaries
types = []
for i in range(len(results1)):
    types.append(type(results1[i]))

# %%
# pull all float values into a list to review
floats = []
for result in results1:
    if type(result) == float:
        floats.append(result)
    else:
        pass

# %%
results2 = []
for result in results1:
    if type(result) == dict:
        results2.append(result)
    else:
        pass

# %%
results2
# Out:
# [{'vote_count': 2438,
#   'id': 7443,
#   'video': False,
#   'vote_average': 6.6,
#   'title': 'Chicken Run',
#   'popularity': 13.991,
#   'poster_path': '/z0MafJgUnVyVbczicYMkPKKHkBi.jpg',
#   'original_language': 'en',
#   'original_title': 'Chicken Run',
#   'genre_ids': [16, 35, 10751],
#   'backdrop_path': '/b0Zlbk19oTLjKPvb807suPFKBtN.jpg',
#   'adult': False,
#   'overview': 'Having been hopelessly repressed and facing eventual certain death at the British chicken farm where they are held, Ginger the chicken along with the help of Rocky the American rooster decide to rebel and lead their fellow chickens in a great escape from the murderous farmers Mr. and Mrs. Tweedy and their farm of doom.',
#   'release_date': '2000-06-21'},
#  {'vote_count': 0,
#   'id': 520758,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Chicken Run 2',
#   'popularity': 1.462,
#   'poster_path': '/wQJW29RIMFQFV46eTLLmTrorjDB.jpg',
#   'original_language': 'en',
#   'original_title': 'Chicken Run 2',
#   'genre_ids': [16],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A sequel to the 2000 film, "Chicken Run."',
#   'release_date': '2020-06-12'},
#  {'vote_count': 0,
#   'id': 495607,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Running Around Like A Chicken With Its Head Cut Off',
#   'popularity': 0.6,
#   'poster_path': '/vNTe1R0zg9kEV8bBLEpdovb5Zvr.jpg',
#   'original_language': 'en',
#   'original_title': 'Running Around Like A Chicken With Its Head Cut Off',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Les Blank's first student film, made while at USC, starring Gail Blank, Pieter Van Deusen and Les himself. This short pays homage to Ingmar Bergman's Seventh Seal, the film that inspired Blank to become a filmmaker.",
#   'release_date': '1960-01-01'},
#  {'vote_count': 97,
#   'id': 10697,
#   'video': False,
#   'vote_average': 6.7,
#   'title': 'The Taste of Others',
#   'popularity': 5.907,
#   'poster_path': '/k9R6Omadvp57EoQ4x9nNneig1Nv.jpg',
#   'original_language': 'fr',
#   'original_title': 'Le Goût des autres',
#   'genre_ids': [18, 35, 10749],
#   'backdrop_path': '/evNvMSUYYjZBluXuZEV9JpqNUel.jpg',
#   'adult': False,
#   'overview': 'Agnès Jaoui co-writes and directs this romantic comedy of manners set in France\'s rustic Provence. Unpolished and ultra-pragmatic industrialist Jean-Jacques Castella (co-scripter Jean-Pierre Bacri) reluctantly attends Racine\'s tragedy "Berenice" in order to see his niece play a bit part. He is taken with the play\'s strangely familiar-looking leading lady Clara Devaux (Anne Alvaro). During the course of the show, Castella soon remembers that he once hired and then promptly fired the actress as an English language tutor. He immediately goes out and signs up for language lessons. Thinking that he is nothing but an ill-tempered philistine with bad taste, Clara rejects him until Castella charms her off her feet.',
#   'release_date': '2000-03-01'},
#  {'vote_count': 6,
#   'id': 41276,
#   'video': False,
#   'vote_average': 6,
#   'title': 'The Life and Times of Hank Greenberg',
#   'popularity': 0.6,
#   'poster_path': '/q5L7XLJ4ylDAs0txMMREbwuoudD.jpg',
#   'original_language': 'en',
#   'original_title': 'The Life and Times of Hank Greenberg',
#   'genre_ids': [99, 10751],
#   'backdrop_path': '/WeDJNcoIJDC6FvcC19dEHz09XR.jpg',
#   'adult': False,
#   'overview': 'The story of Baseball Hall-of-Famer Hank Greenberg is told through archival film footage and interviews with Jewish and non-Jewish fans, his former teammates, his friends, and his family. As a great first baseman with the Detroit Tigers, Greenberg endured antisemitism and became a hero and source of inspiration throughout the Jewish community, not incidentally leading the Tigers to Major League dominance in the 1930s. Written by George S. Davis',
#   'release_date': '2000-01-12'},
#  {'vote_count': 156,
#   'id': 25538,
#   'video': False,
#   'vote_average': 8,
#   'title': 'Yi Yi',
#   'popularity': 6.59,
#   'poster_path': '/hTPkCpK9SLGDMXRbUwzoep0MxOx.jpg',
#   'original_language': 'zh',
#   'original_title': '一一',
#   'genre_ids': [18, 10749],
#   'backdrop_path': '/r3IJLWkORZWJD7v9yT4yFzp2XQ6.jpg',
#   'adult': False,
#   'overview': "Each member of a family in Taipei asks hard questions about life's meaning as they live through everyday quandaries.",
#   'release_date': '2000-09-20'},
#  {'vote_count': 40,
#   'id': 25474,
#   'video': False,
#   'vote_average': 6.8,
#   'title': 'Accident',
#   'popularity': 3.891,
#   'poster_path': '/8CwreRof98cUJFJhQlqc5YVdZ7C.jpg',
#   'original_language': 'cn',
#   'original_title': 'Yi ngoi',
#   'genre_ids': [28, 18, 53],
#   'backdrop_path': '/ryTTmKkuAndi5U58mlSlSY0SAA1.jpg',
#   'adult': False,
#   'overview': 'A self-styled accident choreographer, the Brain is a professional hitman who kills his victims by trapping them in well crafted accidents that look like unfortunate mishaps but are in fact perfectly staged acts of crime. When the teams next assignment goes disastrously wrong, Brain begins to suspect that someone else has planned an ‘accident’ on them.',
#   'release_date': '2009-09-24'},
#  {'vote_count': 3,
#   'id': 337302,
#   'video': False,
#   'vote_average': 5,
#   'title': '10000 Years Later',
#   'popularity': 1.112,
#   'poster_path': '/nyQBg6NsxpFmTAMBPaT69MBdh5w.jpg',
#   'original_language': 'zh',
#   'original_title': 'Yi wan nian yi hou',
#   'genre_ids': [14, 16],
#   'backdrop_path': '/waouCyGVrZiqm605YjqPLzNAyMC.jpg',
#   'adult': False,
#   'overview': 'Hundreds of thousands of years after the collapse of civilization, the world is a post-tech wasteland, and is inhabited by humanoid tribes. The Peace held between them is threatened by the return of Wushen, an evil shape-shifting ghost of modern technology. Wushen threatens to enslave the world population. Zhuma, a ten-year-old girl is the heroine of the story, accompanied by Zhanggong, her lion-like Tibetan Mastiff dog. Chosen, and helped by a ethereal goddess she must assemble a band of allies from the surviving tribes to fight Wushen, and stop him from gaining control over an ancient power.',
#   'release_date': '2015-03-27'},
#  {'vote_count': 2,
#   'id': 74273,
#   'video': False,
#   'vote_average': 3.5,
#   'title': 'Vampire Settle On Police Camp',
#   'popularity': 1.569,
#   'poster_path': '/derUlaU0472CfhHgXMs6G1ApYDM.jpg',
#   'original_language': 'en',
#   'original_title': 'Yi mei dao gu',
#   'genre_ids': [27, 28],
#   'backdrop_path': '/t09RCQ6elr7pW0KE0vXolKYgm4H.jpg',
#   'adult': False,
#   'overview': 'Police School is haunted. Chan Sir and Tong Sir in order to drive out the ghosts, so they find out nine police, who is the dragon-year born, to practice an array. Because of arrogant of Inspector Li Lan Yuk, makes others with bad feeling. They decide to play a trick on her and have lots of joke. They know the goal of training is to seize the ghosts, they all left the training. But the camp is already controlled by the ghosts, causes they stay here to help Chan to seize the ghosts. In Lunar night, on July 14, Chan unable to seize the ghosts, Madam Lee takes out the family secrets and turns into a Taoist priestess to fight with the ghosts. At last, Lee and master drive out all the ghosts',
#   'release_date': '1990-06-07'},
#  {'vote_count': 1,
#   'id': 64985,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Black Lizard',
#   'popularity': 1.4,
#   'poster_path': '/nA5RxYiVb6Uf6XMOnAq91pmoFsg.jpg',
#   'original_language': 'en',
#   'original_title': 'Hei xi yi',
#   'genre_ids': [28, 18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Director Chu Yuan uses two editors and three martial arts choreographers to tell a maacabre tale of kidnapping, murder, frame-ups, and even being buried alive. Swordsmen and women struggle to save their true loves...and their sanity.',
#   'release_date': '1981-11-26'},
#  {'vote_count': 0,
#   'id': 535690,
#   'video': False,
#   'vote_average': 0,
#   'title': 'A Strange Woman',
#   'popularity': 1.4,
#   'poster_path': None,
#   'original_language': 'zh',
#   'original_title': 'Yi dai yao ji',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Not seen in Hong Kong for many years, A Strange Woman was Li Pingqian's first film at Great Wall Film Studio. Adapted from the play La Tosca by French playwright Victorien Sardou, opera star Xiao Xiangshui (Bai Guang) helps her lover, a revolutionary, to escape from warlords. She finesses with both the head of the secret service (Yan Jun) and her lover's wife, but things do not turn out as planned. Li changed his usual pace to encompass a more conventional and dramatic film plot. Bold and flirtatious in her role, Bai Guang is equally over the top in appearance as Yan Jun. The tension in winning the heroine over drives the plot more than the themes of patriotism and loyalty in love.",
#   'release_date': '1950-01-01'},
#  {'vote_count': 0,
#   'id': 583787,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Yi chu hao xi',
#   'popularity': 1.4,
#   'poster_path': None,
#   'original_language': 'zh',
#   'original_title': 'Yi chu hao xi',
#   'genre_ids': [35, 18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '2018-08-09'},
#  {'vote_count': 5,
#   'id': 107714,
#   'video': False,
#   'vote_average': 5.9,
#   'title': 'Return of the Bastard Swordsman',
#   'popularity': 1.346,
#   'poster_path': '/9ygquhVImOG8gED7STeTc6tDQGe.jpg',
#   'original_language': 'en',
#   'original_title': 'Bu yi shen xiang',
#   'genre_ids': [28],
#   'backdrop_path': '/r1MWgiOK1sv3BLgu3jiFcyhoL4M.jpg',
#   'adult': False,
#   'overview': 'Just when audiences thought the director couldn\'t get more spectacular and outrageous, he unleashed this eye-filling, mind-bending "Martial Arts World" sequel of clan rivalries, ninja atrocities, wizard sorceries, and the mythical Silkworm style that changes our hero into a veritable Spider-swordsman. The screen practically explodes with colorful characters and kung-fu -- all directed, co-written, and co-choreographed by Lu Chun-ku, and showcasing some of the best Shaw Brothers action stars. The original Bastard Swordsman was just the beginning, this superlative cult classic that out-phantasmagoricals the original.',
#   'release_date': '1984-05-08'},
#  {'vote_count': 7,
#   'id': 50718,
#   'video': False,
#   'vote_average': 7.9,
#   'title': 'One Day',
#   'popularity': 1.304,
#   'poster_path': '/uMFZchEhaNd3NSIkWfnTu4MkBVN.jpg',
#   'original_language': 'zh',
#   'original_title': '有一天',
#   'genre_ids': [18, 10749, 878],
#   'backdrop_path': '/dMmMK5gWmVlCBXT3SMfkh7UAjXm.jpg',
#   'adult': False,
#   'overview': 'A woman is transported into a world as strange and beautiful as her dreams in this fantasy. Singing (Nikki Hsin-Ying Hsieh), who comes from a family of poor shopkeepers, earns her living as a cleaning woman on a ferry that services a military base. Singing has a recurring dream in which she meets a handsome stranger who speaks in language she cannot understand, and one day on the ferry she meets Tsai Hsien-tsung (Bryan Chang), a soldier who resembles the man in her dreams. The soldier is immediately smitten with Singing, and when the power goes out on the ferry, the two are thrown into a strange netherworld where they sail to South America on a deserted vessel as Singing loses her heart to the military man.',
#   'release_date': '2010-02-07'},
#  {'vote_count': 0,
#   'id': 355421,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Auntie Lan',
#   'popularity': 0.877,
#   'poster_path': '/44VMoHZUepXE6UwM8w8vwyTiVJG.jpg',
#   'original_language': 'en',
#   'original_title': 'Lan yi',
#   'genre_ids': [10749, 18],
#   'backdrop_path': '/aBCuNe1uw5VtbRikKWQ9eTQZ4lq.jpg',
#   'adult': False,
#   'overview': 'A young woman lost her fiancé from the plane clash , later she discover that she becomes pregnant with his baby.She question herself what should she do between keep the child safe until she give a birth or she abortion the child.',
#   'release_date': '1967-03-02'},
#  {'vote_count': 1,
#   'id': 237403,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Iron Head',
#   'popularity': 1.12,
#   'poster_path': '/p3ne2yRsPj1zoPO9jcVJtb5OAfB.jpg',
#   'original_language': 'en',
#   'original_title': 'Wu long jiao yi',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A bumbling martial arts teacher has the skills but lacks the confidence to use them.  Run out of town by some ne'er-do-wells, he sets out on some comic adventures as he travels the countryside.  Taking up some companions that are as bumbling as he is, the group seems to stumble into one misadventure after another.  Will our hearty band eventually prove their worth with their skills and bring their enemies to justice?",
#   'release_date': '1974-06-07'},
#  {'vote_count': 0,
#   'id': 316955,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Oh! What a Family',
#   'popularity': 1.09,
#   'poster_path': '/u5lq8MCBg1ZkHKyvGgxEoEoCFNE.jpg',
#   'original_language': 'zh',
#   'original_title': 'Qiao zhe yi jiazi',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '1979-01-01'},
#  {'vote_count': 0,
#   'id': 360609,
#   'video': False,
#   'vote_average': 0,
#   'title': 'House of the Invisibles',
#   'popularity': 0.6,
#   'poster_path': '/5xwbRJilNl1d9G5L8C4LcydagJM.jpg',
#   'original_language': 'cn',
#   'original_title': 'Yi Lou Yi Gui',
#   'genre_ids': [27],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The inhabitants of a decrepit inner-city tenement building are terrified to discover that the malevolent spirit of a former tenant has been summoned when one of the current residents broke an unspoken vow. Now, as demolition day draws near, the enraged entity sets out to cause as much mischief as possible before the wrecking ball strikes.',
#   'release_date': '2007-01-25'},
#  {'vote_count': 85,
#   'id': 34179,
#   'video': False,
#   'vote_average': 6.5,
#   'title': '14 Blades',
#   'popularity': 4.96,
#   'poster_path': '/dAMh7PtMRpjLLiwdWyzOAwZucPI.jpg',
#   'original_language': 'zh',
#   'original_title': '錦衣衛',
#   'genre_ids': [18, 28, 53],
#   'backdrop_path': '/xji4jDRASuAUsJCPk70yotMFcfo.jpg',
#   'adult': False,
#   'overview': 'Trained in clandestine combat from childhood, the Jinyiwei were masters of the 14 Blades; eight being for torture, five for killing, and the last blade reserved for suicide when a mission failed. An elite force of secret agents with a license to kill, the Jinyiwei devoted their lives and lethal prowess to the service of the Emperor alone. When the Imperial Court is taken over by evil eunuch Jia (Law Kar Ying), the best of the Jinyiwei, Qinglong (Donnie Yen) is assigned to steal a list identifying those still loyal to the Emperor. However unbeknownst to Qinglong, the Jinyiwei have fallen under the control of Jia, and during the mission Qinglong is betrayed and barely escapes with his life. Now as the most wanted man in the land, Qinglong must seek out and rally the loyalists to rise against Jia and restore the Emperor to power. In his way are the deadliest assassins in the land, his former brethren, the Jinyiwei.',
#   'release_date': '2010-02-04'},
#  {'vote_count': 3,
#   'id': 64990,
#   'video': False,
#   'vote_average': 6,
#   'title': 'Heaven Sword and Dragon Sabre II',
#   'popularity': 2.388,
#   'poster_path': '/c6WV40xH9ZkfqbqvHA59pyji6I.jpg',
#   'original_language': 'en',
#   'original_title': 'Yi tian tu long ji da jie ju',
#   'genre_ids': [28, 18, 14],
#   'backdrop_path': '/b2MJzKTSmjByJ3jXVjSEnDRDGCu.jpg',
#   'adult': False,
#   'overview': 'The thrills continue in this second part of this cherished adventure, created by the renowned director Chu Yuan and ingenious novelist Chin Yung. Only the union of the title weapons can save the six remaining martial arts sects who are vying for mastery. So just sit back and enjoy the movie event which spawned a legacy that continues even today with a long-running, internationally loved television series, a role-playing game, and even collectible replicas of the Heaven Sword and Dragon Sabre themselves!',
#   'release_date': '1978-10-27'},
#  {'vote_count': 1,
#   'id': 465992,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Guo Ming Yi',
#   'popularity': 0.625,
#   'poster_path': '/v1RDIUi16BDpj27FZx5pIVzaSRq.jpg',
#   'original_language': 'zh',
#   'original_title': '郭明义',
#   'genre_ids': [18],
#   'backdrop_path': '/wfrqAhXoEJQM4TEubOv5G36UZt8.jpg',
#   'adult': False,
#   'overview': 'In 2011, a movie biography of Guo Mingyi was Produced. The movie was directed by Chen Guoxing and Wang Jing, with the lead part played by Hou Yong and supporting parts by Jiang Hongbo, Li Qin and Feng.',
#   'release_date': '2011-07-15'},
#  {'vote_count': 2,
#   'id': 129171,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Fox Ghost',
#   'popularity': 2.184,
#   'poster_path': '/xEoGh1IL3AGrrqoAhcjuYgHbX3D.jpg',
#   'original_language': 'cn',
#   'original_title': 'Liao zhai zhi yi: Nie yu gu gui',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'To is a "diamond"--a handsome, outstanding student and always wins women\'s hearts. He is honored by tycoon Keung and soon married his daughter. To prepare for the upcoming exam, To moves in an abandoned house. During his stay, he meets two sexy, beautiful, and troublesome ghosts. However, he manages to tame them and falls in love with them. While he is on the way to the exam, he gets dragged in a dangerous situation. To asks the two ghosts for help...',
#   'release_date': '2002-01-01'},
#  {'vote_count': 38,
#   'id': 24922,
#   'video': False,
#   'vote_average': 6.4,
#   'title': 'Ebola Syndrome',
#   'popularity': 3.735,
#   'poster_path': '/slWmF08D96weToG2LkCbP5HSH3Z.jpg',
#   'original_language': 'cn',
#   'original_title': '伊波拉病毒',
#   'genre_ids': [27, 80, 35],
#   'backdrop_path': '/vqVmagaI2eNiPHE3woyzJAHFiD8.jpg',
#   'adult': False,
#   'overview': 'A restaurant employee wanted for murder contracts Ebola by raping a woman in South Africa and starts an outbreak there and in Hong Kong when he returns home.',
#   'release_date': '1996-06-15'},
#  {'vote_count': 0,
#   'id': 415107,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Hwang Jin Yi',
#   'popularity': 0.6,
#   'poster_path': '/sZMoJPUhuezhZFaVbfDidYHyI4z.jpg',
#   'original_language': 'ko',
#   'original_title': '황진이',
#   'genre_ids': [10749, 18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Magistrate Hwang's daughter Jin-yi, is jilted before her wedding because a shoe maker was smitten with her and commits suicide. Jin-yi becomes a courtesan, and becomes famous for her wits and beauty. She falls for Byuk Kye-su, but he's chosen to be an envoy to a far off kingdom. When he leaves she feels so betrayed she takes to a life of wandering. She meets Lee Saeng, a destitute scholar, and stays with him until she discovers he's going to sell her to a group of itinerate clowns. Instead, she joins them willingly.",
#   'release_date': '1986-09-18'},
#  {'vote_count': 3,
#   'id': 40896,
#   'video': False,
#   'vote_average': 7.3,
#   'title': 'Chicken Poets',
#   'popularity': 1.429,
#   'poster_path': '/ciFRyhSsZwo8vfDKkQ5tqf7SdlO.jpg',
#   'original_language': 'zh',
#   'original_title': 'Xiang ji mao yi yang fei',
#   'genre_ids': [18],
#   'backdrop_path': '/kA6gNhUIqGXl8VptF1xJf8AccIB.jpg',
#   'adult': False,
#   'overview': 'Yun Fei, a young poet, seeks the advice of an old university friend who lives in the Beijing suburbs, discovering that his friend has gone into business breeding black chickens. Discouraged about his future as a poet, Yun Fei starts a relationship with a colorblind young girl who encourages him to persevere. But even this new relationship is not enough to inspire him to write. It’s at this point that he buys a pirated record whose magical powers bring him the success he’s longed for. However, sudden fame does not seem to solve everything. The first film of Beijing theatre director Meng Jing Hui, Chicken Poets is an insightful and poetic look at materialism and the younger generation in China.',
#   'release_date': '2002-04-01'},
#  {'vote_count': 136,
#   'id': 14295,
#   'video': False,
#   'vote_average': 7,
#   'title': 'You Can Count on Me',
#   'popularity': 7.413,
#   'poster_path': '/7mGFmij1FZD5eUnNwvUjmpqrDl6.jpg',
#   'original_language': 'en',
#   'original_title': 'You Can Count on Me',
#   'genre_ids': [18, 10749],
#   'backdrop_path': '/hardcwpNmv4soWzTZWWD6OhzsSX.jpg',
#   'adult': False,
#   'overview': "A single mother's life is thrown into turmoil after her struggling, rarely-seen younger brother returns to town.",
#   'release_date': '2000-11-17'},
#  {'vote_count': 7520,
#   'id': 77,
#   'video': False,
#   'vote_average': 8.2,
#   'title': 'Memento',
#   'popularity': 14.229,
#   'poster_path': '/fQMSaP88cf1nz4qwuNEEFtazuDM.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento',
#   'genre_ids': [9648, 53],
#   'backdrop_path': '/puuwLLytKjZuv73SFqBihd6X5ES.jpg',
#   'adult': False,
#   'overview': "Leonard Shelby is tracking down the man who raped and murdered his wife. The difficulty of locating his wife's killer, however, is compounded by the fact that he suffers from a rare, untreatable form of short-term memory loss. Although he can recall details of life before his accident, Leonard cannot remember what happened fifteen minutes ago, where he's going, or why.",
#   'release_date': '2000-10-11'},
#  {'vote_count': 4,
#   'id': 517931,
#   'video': False,
#   'vote_average': 7,
#   'title': 'Memento Mori',
#   'popularity': 1.653,
#   'poster_path': '/mKxltWnGWOdPrvjzAX47WgDOAMN.jpg',
#   'original_language': 'nl',
#   'original_title': 'Memento Mori',
#   'genre_ids': [27, 9648],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Memento Mori is about a girl who's stuck in a dream circle, reliving key moments of a traumatic event. What happened to her? And will she survive this nightmare before time runs out?",
#   'release_date': '2018-04-07'},
#  {'vote_count': 43,
#   'id': 54111,
#   'video': False,
#   'vote_average': 6.2,
#   'title': 'Memento Mori',
#   'popularity': 3.682,
#   'poster_path': '/zpszvqERMuVL7iUCnKGn9Trwnxr.jpg',
#   'original_language': 'ko',
#   'original_title': '여고괴담 두번째 이야기',
#   'genre_ids': [14, 27, 10749],
#   'backdrop_path': '/7cB8R7s1V7oXUniKxn20sshm6hZ.jpg',
#   'adult': False,
#   'overview': 'In this second installment of the Whispering Corridors series, a young girl finds a strange diary, capable of arousing hallucinations, kept by two of her senior fellow-students who seem to have an unusually close bond.',
#   'release_date': '1999-12-24'},
#  {'vote_count': 1,
#   'id': 348128,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': '/nD8ZwEEmSPoLckTFABNJd1Kf11T.jpg',
#   'original_language': 'mk',
#   'original_title': 'Memento',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A day before the earthquake in Skopje, Wily Muller, a German conductor, while passing through the concert meets a young girl Jana, a student from Skopje. After several years they meet again at the "Solidarity Meetings" event, which is held in Skopje, where Wily Muller is a conductor at a concert held on that occasion. Those several days, spent together with the conductor, for Jana mean fulfillment with a kind of reminiscence of her family tragedy experienced during Skopje\'s earthquake, and also a wondering and search for a way of starting life again, which stopped on the day of the earthquake. Although the possibility of going with Muller is very attractive, Jana stays in Skopje. Her place is beside the young man whom she loves and belongs to, with whom she is related with true love...',
#   'release_date': '1967-01-01'},
#  {'vote_count': 0,
#   'id': 346610,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': '/rkJh7yKAFpv884kydTeiJ38zfh.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Experimental short film about car wreckage and automobile safety.',
#   'release_date': '1968-12-31'},
#  {'vote_count': 0,
#   'id': 438742,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': '/fHgIyoLAFyMmHwuEOXz7LpRLqoi.jpg',
#   'original_language': 'de',
#   'original_title': 'Memento',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A film about Jewish cemeteries in East Berlin, based on a screenplay by Günter Kunert, with text by Rabbi Martin Riesenburger. There are shots of gravestones and inscriptions – deported, murdered, perished; in Auschwitz or Theresienstadt. Commentary reminds us of the victims – "in 1933, 160,564 Jewish citizens lived in Berlin; in 1945, 3,500".',
#   'release_date': '1966-02-16'},
#  {'vote_count': 2,
#   'id': 383069,
#   'video': False,
#   'vote_average': 7,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': '/x41LeaHq7LlK4Y2yOZLTzP8UTTE.jpg',
#   'original_language': 'cn',
#   'original_title': 'Memento',
#   'genre_ids': [53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A cop, a blind psychologist, and a mysterious murderer are embroiled in a mental game copying thriller movies. As the suspects are being killed one after another, the case seems to be heading to a dead end. When the answer seems to be knocking at the door, as the murderer finally is exposed and killed, the unexpected is standing right in front of them...',
#   'release_date': '2002-11-28'},
#  {'vote_count': 0,
#   'id': 417615,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Memento',
#   'genre_ids': [9648, 53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A remake of the 2000 film, 'Memento', which centers on a man suffering from short-term memory loss while trying to track down his wife's killer.",
#   'release_date': ''},
#  {'vote_count': 0,
#   'id': 541025,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mori',
#   'popularity': 0.904,
#   'poster_path': '/m1Ma5aOtUi3Zp8zucTbnSKJ6fd3.jpg',
#   'original_language': 'ko',
#   'original_title': '메멘토모리',
#   'genre_ids': [53],
#   'backdrop_path': '/7yhAGnyvMs0jx6iPmi11Oa3rXyu.jpg',
#   'adult': False,
#   'overview': 'Suddenly they woke up. Not knowing who did it, 6 of them got up in the same place. The survival game for 6 people with nothing in common has begun.',
#   'release_date': '2018-06-28'},
#  {'vote_count': 1,
#   'id': 504521,
#   'video': False,
#   'vote_average': 5,
#   'title': "Zadar's Memento",
#   'popularity': 0.6,
#   'poster_path': '/bOEUJTbFUeDX4GfjoEL5xoX2KAv.jpg',
#   'original_language': 'hr',
#   'original_title': 'Zadarski memento',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The painful challenges experienced in the life of a farmer from Zadar, Croatia, in the years from World War I to World War II.',
#   'release_date': '1984-05-20'},
#  {'vote_count': 0,
#   'id': 381742,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento mori',
#   'popularity': 0.6,
#   'poster_path': '/vE2tAsXHBlWf2I60BCc7QQ0RF4l.jpg',
#   'original_language': 'ru',
#   'original_title': 'Мементо мори',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '1991-02-08'},
#  {'vote_count': 0,
#   'id': 374795,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mortis',
#   'popularity': 0.603,
#   'poster_path': '/cYeAwK4ZoxYNtRcKJywQiEyaK3W.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento Mortis',
#   'genre_ids': [27],
#   'backdrop_path': '/ajVOcKxdCcyGOaEW3vJB23vCNin.jpg',
#   'adult': False,
#   'overview': 'A photographer uses dead bodies as props in her erotic photos. Everything was going well until she fell in love.',
#   'release_date': '2015-11-20'},
#  {'vote_count': 1,
#   'id': 208728,
#   'video': False,
#   'vote_average': 7,
#   'title': 'memento mori',
#   'popularity': 0.6,
#   'poster_path': '/dGeseHgEFd8AWZW5wepPkCTEQ7Q.jpg',
#   'original_language': 'en',
#   'original_title': 'memento mori',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'memento mori is a layered exploration of the total photographs captured over the course of a lifetime – over 100,000 in total. This personal archive, the dizzying documentation of a life, represents a plurality of subjects, objects, thoughts, dreams and experiences, forming an encyclopedic index of the possibilities of sight.',
#   'release_date': '2012-09-19'},
#  {'vote_count': 1,
#   'id': 430775,
#   'video': False,
#   'vote_average': 6,
#   'title': 'Memento Mori',
#   'popularity': 0.6,
#   'poster_path': '/3LR3aiNct2wDNPnkXFlhnriwl0q.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento Mori',
#   'genre_ids': [9648, 35],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "After an accident, Daming can't remember what happened last night. Back home, he discovers in his closet the dead body of Gao Yan. Who killed this man hated by so many people included Daming himself?",
#   'release_date': '2016-06-03'},
#  {'vote_count': 0,
#   'id': 271038,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mori',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Memento Mori',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Viewed from the world of Roger Ballen. Ballen is renowned for his confronting and bleak black and white portraits of marginalised South Africans. Melle van Essen follows in Ballen’s footsteps by creating 'Living' photographs with fixed frames and strong black and white contrasts with great emphasis on composition.",
#   'release_date': '2005-09-01'},
#  {'vote_count': 0,
#   'id': 384914,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mori',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'de',
#   'original_title': 'Memento Mori',
#   'genre_ids': [9648, 18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The writer Charmain Colson entertains a circle of old friends. One day, when the group receive an anonymous message saying Memento Mori/Remember you must die, they all panic in fear and angst.',
#   'release_date': '1975-01-05'},
#  {'vote_count': 0,
#   'id': 518808,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Mori',
#   'popularity': 0.6,
#   'poster_path': '/gxNzkGB9PrNmnF7BwKEwRIcAg2K.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento Mori',
#   'genre_ids': [18, 28],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': ''},
#  {'vote_count': 0,
#   'id': 575852,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento Stella',
#   'popularity': 0.6,
#   'poster_path': '/bjDZJrExq0ILGnfHgAt3S3bXBE0.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento Stella',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Makino Takashi takes us to a place where different rules apply. He overwhelms us with his universe, which is built up of countless images, figurative and non-figurative, accompanied by an equally sophisticated soundtrack. At times very abstract and distant, at others almost palpable and narrative. We naturally seek recognition in the infinite layering of the images, and in so doing compose our own story, based on what we ourselves know of the world, using our personal references to help us. In this way, a work arises unique to every viewer, which continues to reverberate long after we leave the cinema.',
#   'release_date': '2019-01-26'},
#  {'vote_count': 0,
#   'id': 369827,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Memento mori',
#   'popularity': 0.6,
#   'poster_path': '/nRNRH27eY6gLBRWDQfLMHMzwAlg.jpg',
#   'original_language': 'ru',
#   'original_title': 'Memento mori',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '1996-01-01'},
#  {'vote_count': 0,
#   'id': 466084,
#   'video': True,
#   'vote_average': 0,
#   'title': 'Memento - A Boulder Life Line',
#   'popularity': 0.6,
#   'poster_path': '/8KUZbcxszWWYFldTwEX3ArwQvCD.jpg',
#   'original_language': 'en',
#   'original_title': 'Memento - A Boulder Life Line',
#   'genre_ids': [28, 12, 99],
#   'backdrop_path': '/gt9LrJa6GfWZcjv4nE1NhR6zuDg.jpg',
#   'adult': False,
#   'overview': 'What happens when a crazy filmmaker meets a crazy boulder and they decide to make a film together? It could be called pre-programmed chaos or the beginning of a common vision. After nearly two years of work, the film is finished, pure soul has come out! Camera and direction show boulders in a unique style. The philsophy and climbing art of Bernd Zangerl set the crown on the film. The locations were Ticino, Magic Wood and the mountains of the Silvretta. Each area has its own character, its own style and ambience. \'Every centimeter has its meaning. As with Humbold\'s natural vision, thought and feeling merge, and here the symbiosis of man and rock, man\'s stone, humanized petrified. "  The film shows Bernd Zangerl, Barbara Zangerl and Thomas "Steini" Steinbrugger during bouldering at Magic Wood, Silvretta and Ticino. The best and most beautiful first visits by Bernd Zangerl are documented as well as spectacular highballs and low water soloing.',
#   'release_date': '2006-01-01'},
#  {'vote_count': 249,
#   'id': 13785,
#   'video': False,
#   'vote_average': 7.1,
#   'title': 'Best in Show',
#   'popularity': 7.822,
#   'poster_path': '/rDoVUVT5CGkraBjEukfBTHsxBN9.jpg',
#   'original_language': 'en',
#   'original_title': 'Best in Show',
#   'genre_ids': [35],
#   'backdrop_path': '/ed8CWIUFrjFYEcJP1C8uc3wEcNM.jpg',
#   'adult': False,
#   'overview': 'The tension is palpable, the excitement is mounting and the heady scent of competition is in the air as hundreds of eager contestants from across America prepare to take part in what is undoubtedly one of the greatest events of their lives -- the Mayflower Dog Show. The canine contestants and their owners are as wondrously diverse as the great country that has bred them.',
#   'release_date': '2000-09-19'},
#  {'vote_count': 0,
#   'id': 352510,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Fantasia in Best Show Minor',
#   'popularity': 0.6,
#   'poster_path': '/emLJJTg26z084sKNSAZBO5hCzqq.jpg',
#   'original_language': 'en',
#   'original_title': 'Fantasia in Best Show Minor',
#   'genre_ids': [35],
#   'backdrop_path': '/oOJ4kVrJgFv0F0mKDGEgNIrYafG.jpg',
#   'adult': False,
#   'overview': 'Fantasia in Best Show Minor is the first and only ever Best Show on WFMU DVD Release! It features stuff you’re never going to believe, puppets. animation, sketches, travelogues from callers, and guest appearances from Patton Oswalt, Ted Leo, Paul F. Tompkins, Zach Galifinakis, Fucked Up, Tim and Eric, John Hodgeman, Aimee Mann, Scharpling and Wurster, Yo La Tengo, Kurt Vile, Matt Fracton, Todd Barry, and Jason Woliner. The DVD was available exclusively during the 2010 WFMU pledge drive.',
#   'release_date': '2010-01-01'},
#  {'vote_count': 0,
#   'id': 338169,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Strawberry Shortcake: Berry Best in Show',
#   'popularity': 0.6,
#   'poster_path': '/gwfkWB5BL2cYUpAuxs999n17MBK.jpg',
#   'original_language': 'en',
#   'original_title': 'Strawberry Shortcake: Berry Best in Show',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Strawberry Shortcake and her pals meet some new furry friends in these delightful "tails" about being yourself and encouraging others to do the same. Strawberry helps out some stray pooches in "A Boy and His Dogs." Blueberry Muffin and Huck become "Partners in Crime" when they try to write a mystery story. And the girls start a dog shelter in "The Mystery of the Disappearing Dog Show."',
#   'release_date': '2015-04-28'},
#  {'vote_count': 964,
#   'id': 1900,
#   'video': False,
#   'vote_average': 7,
#   'title': 'Traffic',
#   'popularity': 14.877,
#   'poster_path': '/9qPLd5hdXIlrAyknVWK38eZyUMo.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic',
#   'genre_ids': [53, 18, 80],
#   'backdrop_path': '/ivAC8eZkzKoTf8EWQh7pkFD0AGS.jpg',
#   'adult': False,
#   'overview': "An exploration of the United States of America's war on drugs from multiple perspectives. For the new head of the Office of National Drug Control Policy, the war becomes personal when he discovers his well-educated daughter is abusing cocaine within their comfortable suburban home. In Mexico, a flawed, but noble policeman agrees to testify against a powerful general in league with a cartel, and in San Diego, a drug kingpin's sheltered trophy wife must learn her husband's ruthless business after he is arrested, endangering her luxurious lifestyle.",
#   'release_date': '2000-12-27'},
#  {'vote_count': 14,
#   'id': 142948,
#   'video': False,
#   'vote_average': 7.5,
#   'title': 'Traffic',
#   'popularity': 1.896,
#   'poster_path': '/3ficNeBPB03vUZ9N7okWftKpyr9.jpg',
#   'original_language': 'ml',
#   'original_title': 'ട്രാഫിക്',
#   'genre_ids': [53],
#   'backdrop_path': '/tx0KFYxQ9atSOSflbnJzaIGEGlm.jpg',
#   'adult': False,
#   'overview': 'An emotional thriller based on a road trip from Kochi to Palakkad. Inspired from the real events that happened in Chennai.',
#   'release_date': '2011-01-07'},
#  {'vote_count': 153,
#   'id': 11129,
#   'video': False,
#   'vote_average': 6.8,
#   'title': 'Human Traffic',
#   'popularity': 7.067,
#   'poster_path': '/4FmaeS2uBVhpjnFuGphV5lAKXZ7.jpg',
#   'original_language': 'en',
#   'original_title': 'Human Traffic',
#   'genre_ids': [35, 18],
#   'backdrop_path': '/zGjyVVWkqF8ywo49ISp3bBhWmPo.jpg',
#   'adult': False,
#   'overview': 'Five twenty-something friends spend a drug-fueled weekend in Cardiff, Wales.',
#   'release_date': '1999-06-04'},
#  {'vote_count': 2,
#   'id': 504195,
#   'video': False,
#   'vote_average': 4,
#   'title': 'Traffic Ramasamy',
#   'popularity': 1.785,
#   'poster_path': '/q1SvwdOxC3OhZii5pagDTJGsU6V.jpg',
#   'original_language': 'ta',
#   'original_title': 'டிராஃபிக் ராமசாமி',
#   'genre_ids': [18],
#   'backdrop_path': '/5qCkEMX7taLJaGEXv5BSdC1r73r.jpg',
#   'adult': False,
#   'overview': 'Social activist Traffic Ramasamy takes on the corrupt and powerful in his quest for justice. Can he succeed to bring them down, especially when they are keen to finish him off for good?',
#   'release_date': '2018-06-22'},
#  {'vote_count': 30,
#   'id': 30593,
#   'video': False,
#   'vote_average': 6.9,
#   'title': 'Heavy Traffic',
#   'popularity': 1.857,
#   'poster_path': '/A9jsB1t49L0p0mD7Wqn9Y4WVFkh.jpg',
#   'original_language': 'en',
#   'original_title': 'Heavy Traffic',
#   'genre_ids': [16, 35, 18],
#   'backdrop_path': '/458a7UKoPEN9HvNEwtLhqyPSoXj.jpg',
#   'adult': False,
#   'overview': 'An "underground" cartoonist contends with life in the inner city, where various unsavory characters serve as inspiration for his artwork.',
#   'release_date': '1973-08-08'},
#  {'vote_count': 61,
#   'id': 60046,
#   'video': False,
#   'vote_average': 7.7,
#   'title': 'The Traffic Policeman',
#   'popularity': 3.745,
#   'poster_path': '/o4zNFZ698gjr4D1ZaxNp0t7kPuM.jpg',
#   'original_language': 'it',
#   'original_title': 'Il vigile',
#   'genre_ids': [35],
#   'backdrop_path': '/vXducRNWdj4mcj3ssuXmvrh4pjz.jpg',
#   'adult': False,
#   'overview': 'An unemployed man gets a job as traffic policeman but the traffic in the big city creates innumerous problems for the poor guy.',
#   'release_date': '1960-01-01'},
#  {'vote_count': 7,
#   'id': 162285,
#   'video': False,
#   'vote_average': 6.1,
#   'title': 'Traffic Troubles',
#   'popularity': 1.437,
#   'poster_path': '/4fKAbYu40B0YmXqpsw8JAoJKwEx.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic Troubles',
#   'genre_ids': [16],
#   'backdrop_path': '/hdC7IfRCfIlMdFGwiyOjybWyxPo.jpg',
#   'adult': False,
#   'overview': 'Mickey is driving a taxi. His first fare is a very large gentleman. Mickey stops traffic and gets a tongue-lashing from the officer. The cab runs into some bad road, bounces the fare down to almost nothing, then bounces the customer right out of the cab. Mickey pulls up to the curb and picks up his second passenger, Minnie. She plays her accordion while they ride. The cab gets a flat tire, and Mickey uses a pig to pump it up.',
#   'release_date': '1931-03-16'},
#  {'vote_count': 14,
#   'id': 491206,
#   'video': False,
#   'vote_average': 6.2,
#   'title': 'Traffic Stop',
#   'popularity': 1.414,
#   'poster_path': '/kRVMLMn7uSyTrkg565j16kW6NgS.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic Stop',
#   'genre_ids': [99],
#   'backdrop_path': '/aJBXzOMnSOGX7T7SpUvMXIcByjm.jpg',
#   'adult': False,
#   'overview': 'Breaion King, a 26 year-old African-American school teacher from Austin, Texas,- is pulled over for a routine traffic stop that escalates into a violent arrest. Dashcam clips intercut with verite scenes tell a story of racism in law enforcement through the eyes of one of its victims.',
#   'release_date': '2017-11-14'},
#  {'vote_count': 2,
#   'id': 175240,
#   'video': False,
#   'vote_average': 7.5,
#   'title': 'Point Doom',
#   'popularity': 1.472,
#   'poster_path': '/pXRiIxYCeaw3LwRhsERJqgfjKq1.jpg',
#   'original_language': 'en',
#   'original_title': 'Point Doom',
#   'genre_ids': [28, 53, 80],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A Hollywood talent agent's girlfriend thrusts him into a world of strip clubs, drugs and deadly motorcycle gangs.",
#   'release_date': '2000-06-08'},
#  {'vote_count': 0,
#   'id': 463156,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Traffic',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Traffic',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Traffic 2014 Telugu Movie',
#   'release_date': ''},
#  {'vote_count': 0,
#   'id': 490165,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Traffic',
#   'popularity': 0.6,
#   'poster_path': '/cDH417FT8UhHGPmMWQD5r69d3Nz.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Pursuing a visual search regarding a reference that is common to other works, this audiovisual essay highlights the affinity between nature and labor. We are now able to see the ancestral tension between the organic and the artificial poetically dwell in the static shot, where the choreography of the birds, the rational metric of the constructors and the lapping of the water in the background coexist.',
#   'release_date': '2015-01-01'},
#  {'vote_count': 1,
#   'id': 480884,
#   'video': False,
#   'vote_average': 5,
#   'title': 'Traffic',
#   'popularity': 0.6,
#   'poster_path': '/hpKwseS35j4SeZ8BGkhkKV5scbt.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The real truth behind the child protection system. Social workers, Judges, Lawyers and Guardians of the court all working together to secure the removal of children from their families and traffic them around the UK.',
#   'release_date': '2014-11-30'},
#  {'vote_count': 4,
#   'id': 128856,
#   'video': False,
#   'vote_average': 4.5,
#   'title': 'Traffic Affairs',
#   'popularity': 1.056,
#   'poster_path': '/gn52TI8EB6OoZB27RsWwqBquvWj.jpg',
#   'original_language': 'de',
#   'original_title': 'Mitfahrer – Jede Begegnung ist eine Chance',
#   'genre_ids': [18, 28, 53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': '',
#   'release_date': '2004-02-06'},
#  {'vote_count': 34,
#   'id': 16464,
#   'video': False,
#   'vote_average': 5.9,
#   'title': 'Traffic Crossing Leeds Bridge',
#   'popularity': 1.473,
#   'poster_path': '/tI7SfgAWbNLtby4whM9MxVve4IA.jpg',
#   'original_language': 'xx',
#   'original_title': 'Traffic Crossing Leeds Bridge',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A film by Louis Aimé Augustin Le Prince, shot in late October 1888, showing pedestrians and carriages crossing Leeds Bridge.',
#   'release_date': '1888-10-15'},
#  {'vote_count': 3,
#   'id': 191098,
#   'video': False,
#   'vote_average': 7.7,
#   'title': 'Traffic Officer',
#   'popularity': 1.4,
#   'poster_path': '/1g21kSoGm9OUP0ZEidTfbAGhQj8.jpg',
#   'original_language': 'ru',
#   'original_title': 'Inspektor GAI',
#   'genre_ids': [35, 18],
#   'backdrop_path': '/bskX5Y4xGMnkdQ06CRfxSHje4jN.jpg',
#   'adult': False,
#   'overview': 'A comic drama about a permanently going duel between Traffic Officer and powerful businessman.',
#   'release_date': '1982-06-06'},
#  {'vote_count': 3,
#   'id': 54917,
#   'video': False,
#   'vote_average': 7.3,
#   'title': 'Traffic Warden',
#   'popularity': 0.937,
#   'poster_path': '/xTfqDq9JRYJrYDuwOr5XalyGrxT.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic Warden',
#   'genre_ids': [35],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A comic short – in fact, a bite-size romantic comedy – in which a serendipitous series of events leads a traffic warden (played by David Tennant) to find true love.',
#   'release_date': '2005-01-01'},
#  {'vote_count': 25,
#   'id': 167179,
#   'video': False,
#   'vote_average': 6.9,
#   'title': 'Traffic Department',
#   'popularity': 2.358,
#   'poster_path': '/5iDhJc9NfOI3IMnmzAL8TJe3fNu.jpg',
#   'original_language': 'pl',
#   'original_title': 'Drogówka',
#   'genre_ids': [18, 80],
#   'backdrop_path': '/1lJfWBTiOTDkv2ThBtKhDfLP7sq.jpg',
#   'adult': False,
#   'overview': 'Seven policemen, seven deadly sins, a murder case, secrets and the filth of everyday police work: Traffic Department transports the viewer into the darkest Warsaw streets.',
#   'release_date': '2013-01-31'},
#  {'vote_count': 3,
#   'id': 46426,
#   'video': False,
#   'vote_average': 6.7,
#   'title': 'Traffic Signal',
#   'popularity': 0.953,
#   'poster_path': '/r5fwik43w0BG1pKTgvSuySwtToN.jpg',
#   'original_language': 'en',
#   'original_title': 'Traffic Signal',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Silsila is the "manager" of one traffic signal, that is he collects the "hafta" (protection tax) from each signal squatter plying his trade. There\'s Tsunami, a little scavenger boy, there\'s Rani - a Gujrati girl selling ethnic clothes on the sidewalk, and there\'s Dominic - a drug addict and the prostitute who feels for him...',
#   'release_date': '2007-02-07'},
#  {'vote_count': 4,
#   'id': 50118,
#   'video': False,
#   'vote_average': 5.8,
#   'title': 'Traffic',
#   'popularity': 0.775,
#   'poster_path': '/2RJCCdENmWfsujdmbzafdVACRw9.jpg',
#   'original_language': 'pt',
#   'original_title': 'Tráfico',
#   'genre_ids': [35],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Young Jesus (Joaquim Oliviera) is taken on a vacation by his parents (Rita Blanco, Adriano Luz) to a deserted beach resort. They accidentally fall into overnight wealth after Jesus digs in the sand, uncovering a large drug stash. Others characters intersecting here include an alcoholic actress, a philandering banker, a general trafficking in arms, priests who close their church and head north as hitchhikers, politicians who watch an all-girl production of Julius Caesar, and beggars who recite a children's story in a huge heap of trash.",
#   'release_date': '1998-12-31'},
#  {'vote_count': 1,
#   'id': 214397,
#   'video': False,
#   'vote_average': 3,
#   'title': 'Girls in the Night Traffic',
#   'popularity': 1.627,
#   'poster_path': '/pSg53acAsE4EMv942GrjQR5dSSw.jpg',
#   'original_language': 'de',
#   'original_title': 'Mädchen im Nachtverkehr',
#   'genre_ids': [18, 35],
#   'backdrop_path': '/hK35I08sEzrMMTA97HqNI8QA0hp.jpg',
#   'adult': False,
#   'overview': 'Three prostitutes living together in a large apartment and tells stories about their quirky cods. Then tricked into white slavery by the murky Turk Mustafa and taken to a harem in the Middle East! They use their cunning and seduction skills to try to escape.',
#   'release_date': '1976-07-13'},
#  {'vote_count': 109,
#   'id': 12706,
#   'video': False,
#   'vote_average': 6.9,
#   'title': 'Croupier',
#   'popularity': 4.482,
#   'poster_path': '/s8wDHdBDGiBuVeQDP9mdm9u3b9U.jpg',
#   'original_language': 'en',
#   'original_title': 'Croupier',
#   'genre_ids': [18, 53],
#   'backdrop_path': '/obZPzdJ3SmfGnoXtzMc58w5QjIx.jpg',
#   'adult': False,
# ...
#   'release_date': '2017-05-03'},
#  {'vote_count': 0,
#   'id': 261473,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Million Dollars Snatch',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Qi bai wan yuan da jie an',
#   'genre_ids': [28, 80, 35],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "The grandson of a petroleum company president is kidnapped in Rome. The kidnappers want $10 million dollars in ransom money. The boy's grandfather wants his grandson back but doesn't want to pay, so he hires detectives to go after the boy. Three local detectives have a go at it, and fail with comedic humiliation. While lamenting their frustrations at a Chinese restaurant, they notice two young waiters playfully exchanging martial arts moves and instantly enlist the eldest to get the boy back before the kidnappers cut off his ear.",
#   'release_date': '1976-08-13'},
#  {'vote_count': 0,
#   'id': 358123,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatch of the Day',
#   'popularity': 0.6,
#   'poster_path': '/unamVX3vEezw5lifYybdp3cZv0B.jpg',
#   'original_language': 'en',
#   'original_title': 'Snatch of the Day',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Part of BFI collection "Police and Thieves."',
#   'release_date': '1975-01-02'},
#  {'vote_count': 0,
#   'id': 274882,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatch N Grab',
#   'popularity': 0.6,
#   'poster_path': '/7KBxC7pCOTPQZ6Ct41OfvVwLQKa.jpg',
#   'original_language': 'en',
#   'original_title': 'Snatch N Grab',
#   'genre_ids': [35, 10749],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Tired of being treated poorly by men, four frustrated women devise a game of social conquest to reclaim their destinies. But each is soon challenged to face herself and her relationships while also battling a jealous psycho and sexist boss.',
#   'release_date': '2010-01-01'},
#  {'vote_count': 147,
#   'id': 4722,
#   'video': False,
#   'vote_average': 5.9,
#   'title': 'Body Snatchers',
#   'popularity': 8.489,
#   'poster_path': '/4GLnErLrLfban9JDCOsxB9Xeegq.jpg',
#   'original_language': 'en',
#   'original_title': 'Body Snatchers',
#   'genre_ids': [27, 878, 53],
#   'backdrop_path': '/8rjgIzDtLKucvg2u5zzFCyDFAnb.jpg',
#   'adult': False,
#   'overview': "When Environmental Protection Agency inspector Steve Malone travels to a remote military base in order to check for toxic materials, he brings his family along for the ride. After arriving at the base, his teenage daughter Marti befriends Jean Platt, daughter of the base's commander, General Platt. When people at the base begin acting strangely, Marti becomes convinced that they are slowly being replaced by plant-like aliens.",
#   'release_date': '1993-06-09'},
#  {'vote_count': 396,
#   'id': 11549,
#   'video': False,
#   'vote_average': 7.5,
#   'title': 'Invasion of the Body Snatchers',
#   'popularity': 15.884,
#   'poster_path': '/4oj0G2Zr6tQKBDOzKaLuefdeBsG.jpg',
#   'original_language': 'en',
#   'original_title': 'Invasion of the Body Snatchers',
#   'genre_ids': [27, 878],
#   'backdrop_path': '/eTxgy8eROB5Ly7ZXKLukQoF6tKl.jpg',
#   'adult': False,
#   'overview': 'A small-town doctor learns that the population of his community is being replaced by emotionless alien duplicates.',
#   'release_date': '1956-02-05'},
#  {'vote_count': 0,
#   'id': 580632,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatchers',
#   'popularity': 1.264,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Snatchers',
#   'genre_ids': [27, 878],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Sara’s one of the cool kids... but she’s totally terrified of losing her status. She’d be a lot more secure if she could just win back her super-hot ex, Skyler, but he’s not interested unless they move to the next level...  She decides to take the plunge -- but something about Skyler changed on his summer trip to Mexico... something in his nards.  Sara wakes the next morning only to find that she’s nine-months pregnant. Desperate to keep this under wraps, she turns to the only person she can trust: her nerdy ex-best friend, Hayley.  But after a trip to the clinic results in Sara birthing something other-worldly, the girls realize their night is only just getting started...',
#   'release_date': '2019-03-10'},
#  {'vote_count': 374,
#   'id': 11850,
#   'video': False,
#   'vote_average': 7.3,
#   'title': 'Invasion of the Body Snatchers',
#   'popularity': 7.973,
#   'poster_path': '/skS02wdeH2C0nrbCQP3qKwJdZtZ.jpg',
#   'original_language': 'en',
#   'original_title': 'Invasion of the Body Snatchers',
#   'genre_ids': [27, 9648, 878, 53],
#   'backdrop_path': '/gnVXP708WiJAH6oMhdSRAik4XTl.jpg',
#   'adult': False,
#   'overview': 'The first remake of the paranoid infiltration classic moves the setting for the invasion, from a small town to the city of San Francisco and starts as Matthew Bennell notices that several of his friends are complaining that their close relatives are in some way different. When questioned later they themselves seem changed, as they deny everything or make lame excuses. As the invaders increase in number they become more open and Bennell, who has by now witnessed an attempted "replacement", realises that he and his friends must escape or suffer the same fate. But who can he trust to help him and who has already been snatched?',
#   'release_date': '1978-12-19'},
#  {'vote_count': 64,
#   'id': 30346,
#   'video': False,
#   'vote_average': 7,
#   'title': 'The Body Snatcher',
#   'popularity': 3.894,
#   'poster_path': '/1dOCP2ahMVlA95SivxhEdVvcXZE.jpg',
#   'original_language': 'en',
#   'original_title': 'The Body Snatcher',
#   'genre_ids': [80, 27],
#   'backdrop_path': '/noIqfaKdX3go0GinBAfnnBnYTNh.jpg',
#   'adult': False,
#   'overview': 'Edinburgh, 1831. Among those who undertake the illegal trade of grave robbery is Gray, ostensibly a cab driver. Formerly a medical student convicted of grave robbery, Gray holds a grudge against Dr. MacFarlane who had escaped detection and punishment.',
#   'release_date': '1945-05-25'},
#  {'vote_count': 0,
#   'id': 378918,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatched',
#   'popularity': 0.883,
#   'poster_path': '/2gUnuiXoYTkRG63fp0cP9h9Qp4a.jpg',
#   'original_language': 'en',
#   'original_title': 'Snatched',
#   'genre_ids': [80, 18, 53],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "The wives of three wealthy men are kidnapped and held for a $3 million ransom, but one of the men doesn't want to pay his share.",
#   'release_date': '1973-01-31'},
#  {'vote_count': 21,
#   'id': 22451,
#   'video': False,
#   'vote_average': 4.7,
#   'title': 'The Bone Snatcher',
#   'popularity': 3.284,
#   'poster_path': '/kceAJpK27zaE2IdXU1iIzUHZcIt.jpg',
#   'original_language': 'en',
#   'original_title': 'The Bone Snatcher',
#   'genre_ids': [878, 27],
#   'backdrop_path': '/9uDB03qgISKFvbR6IAQeHyxmukL.jpg',
#   'adult': False,
#   'overview': 'After miners disappear in the Namib Desert, some scientists find their remains and the demonic creature that killed them.',
#   'release_date': '2003-12-23'},
#  {'vote_count': 0,
#   'id': 531530,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Snatchers',
#   'popularity': 0.84,
#   'poster_path': '/5HVZkMsMLifuwsJxw59QQcHRhxL.jpg',
#   'original_language': 'en',
#   'original_title': 'Snatchers',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A teenager's trip to the clinic becomes freakier than usual when she learns that something otherworldly is involved.",
#   'release_date': '2016-03-11'},
#  {'vote_count': 535,
#   'id': 10866,
#   'video': False,
#   'vote_average': 6.4,
#   'title': 'Joy Ride',
#   'popularity': 7.784,
#   'poster_path': '/q8y2T2LvJV0mvia1RA9pS1K33GR.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride',
#   'genre_ids': [9648, 53, 18],
#   'backdrop_path': '/wr9KMaCGGquZQqmjN8mRqOR2FeM.jpg',
#   'adult': False,
#   'overview': 'Three young people on a road trip from Colorado to New Jersey talk to a trucker on their CB radio, then must escape when he turns out to be a psychotic killer.',
#   'release_date': '2001-10-05'},
#  {'vote_count': 96,
#   'id': 16763,
#   'video': False,
#   'vote_average': 5.4,
#   'title': 'Joy Ride 2: Dead Ahead',
#   'popularity': 6.661,
#   'poster_path': '/dYuz2lnKz3ZZY4CsWVGZanm6TMb.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride 2: Dead Ahead',
#   'genre_ids': [80, 53],
#   'backdrop_path': '/lslrLtCMyPgZYtjBR3LKCuG02wB.jpg',
#   'adult': False,
#   'overview': "While driving to Las Vegas for the bachelor party of her sister Melissa and her fiance Bobby, Kayla stops the car in the gas station to meet her date, Nik, a guy she met on the internet. Nik convinces her to take a secondary road under the protest of Bobby but the car breaks down. They find a house in the middle of nowhere and decide to take the car parked in the house's garage to the next city...",
#   'release_date': '2008-10-07'},
#  {'vote_count': 81,
#   'id': 259074,
#   'video': False,
#   'vote_average': 4.7,
#   'title': 'Joy Ride 3',
#   'popularity': 3.251,
#   'poster_path': '/qfZsy4gxrBDvIzoiT0HqFjQgobP.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride 3',
#   'genre_ids': [53],
#   'backdrop_path': '/6LhwAiSscN1ef4c2alt9pjr1au7.jpg',
#   'adult': False,
#   'overview': "Rusty Nail is back on the road again looking to punish injustice at every turn - and this time it's with a group of hotheaded street racers on their way to the Road Rally 1000. As they drive through a desolate shortcut on the way to the race, an encounter with Rusty turns sour and soon he is tracking, teasing and torturing them until the end of the road.",
#   'release_date': '2014-06-03'},
#  {'vote_count': 0,
#   'id': 392055,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.627,
#   'poster_path': '/nIBj2juc0L1gIvuCGOjTypMCoxs.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'Two cousins invite their girlfriends on a joy-ride, but car trouble leads to catastrophe!',
#   'release_date': '1935-12-16'},
#  {'vote_count': 0,
#   'id': 377538,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.6,
#   'poster_path': '/eW7MyFEzTiU2Ho28mD29ZVlDFMX.jpg',
#   'original_language': 'de',
#   'original_title': 'Usfahrt',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The 4th installment of the Dogme 95 Movement.',
#   'release_date': '2000-11-16'},
#  {'vote_count': 0,
#   'id': 208233,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.6,
#   'poster_path': '/xwzH9vP9245Gq0dMvEgMYJNlxaB.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride',
#   'genre_ids': [80, 18],
#   'backdrop_path': '/kX6Mn8UJOaOOpPEW6YXBDst2pAQ.jpg',
#   'adult': False,
#   'overview': "Teenage story of a bad apple in a barrel evolving from a kid's desire to drive a new T-bird.",
#   'release_date': '1958-11-23'},
#  {'vote_count': 0,
#   'id': 281519,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Joy Ride',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "Tony Smalls is a lawyer on the fast track, moving quickly away from his roots in Detroit's rough Joy Road neighborhood. He's forced to put his plans on hold when his sister Nia asks him to defend her fiance, a gang kingpin who is under arrest for a triple murder that he says he didn't commit. Tony feels the pressure of the case when the feds and a shadowy corporation get involved, along with a private investigator who seems to be working all sides. When Nia starts an investigation of her own into the murder, it not only brings her closer to the truth - it puts both herself and Tony in harm's way.",
#   'release_date': '2012-01-01'},
#  {'vote_count': 0,
#   'id': 561948,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Joy Ride',
#   'popularity': 0.6,
#   'poster_path': '/sWk1EeMh63XYbYFmoi87x6xe90T.jpg',
#   'original_language': 'hi',
#   'original_title': 'Joy Ride',
#   'genre_ids': [99],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'A documentary about human-powered manual ferris wheel rides at Juhu beach in Mumbai.',
#   'release_date': '2007-01-01'},
#  {'vote_count': 6,
#   'id': 128056,
#   'video': False,
#   'vote_average': 4.8,
#   'title': 'Joy Ride: An Auto Theft',
#   'popularity': 0.833,
#   'poster_path': '/u4uFzEGzEG4ODciadtP5ERt4i9C.jpg',
#   'original_language': 'en',
#   'original_title': 'Joy Ride: An Auto Theft',
#   'genre_ids': [18],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "In the summer of '76, after pinball and complaining lose their thrill, Val and Tim steal their friend Randal's car.  The boys pick up some girls, Kari and Vicki, and go for a ride up in the hills.  They intend to return the stolen car before Randal finishes baseball practice, but their adolescent hijinks spiral out of control.  The short film seems to be designed to make teenagers see that joyriding isn't just a bit of fun.",
#   'release_date': '1976-01-01'},
#  {'vote_count': 0,
#   'id': 313946,
#   'video': False,
#   'vote_average': 0,
#   'title': 'A Joy Ride',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'A Joy Ride',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': "A Joy Ride is a 1922 animated short subject made by Bray Productions. It is among the many films starring Judge Rummy, the character from Tad Dorgan's comic strips.",
#   'release_date': '1922-06-17'},
#  {'vote_count': 5,
#   'id': 37128,
#   'video': False,
#   'vote_average': 6.4,
#   'title': 'Jolly Fellows',
#   'popularity': 1.067,
#   'poster_path': '/id0tb1Sqhb9XfPj7CfQsaQqOVEo.jpg',
#   'original_language': 'ru',
#   'original_title': 'Весёлые ребята',
#   'genre_ids': [10402, 35],
#   'backdrop_path': '/j79D7lj4WlCq0UtYK3sHT4TwRm4.jpg',
#   'adult': False,
#   'overview': 'Merry Fellows was the first Soviet musical comedy. Set in Odessa and Moscow in the 1930\'s. Shepherd Kostya Potekhin (Utyosov) is mistaken for an international concert star. He falls in love with Anyuta (Orlova) and plays the "star" for her. In a cascade of comic musical numbers he becomes the leader of a Jazz-Band and gives a hilarious show at the Odessa Music Hall. Now he is destined to perform at the Bolshoi Theatre in Moscow.',
#   'release_date': '1934-12-09'},
#  {'vote_count': 2697,
#   'id': 2034,
#   'video': False,
#   'vote_average': 7.4,
#   'title': 'Training Day',
#   'popularity': 12.736,
#   'poster_path': '/sDT2biSB7wzBJdXq9o3ldr7VfvY.jpg',
#   'original_language': 'en',
#   'original_title': 'Training Day',
#   'genre_ids': [28, 80, 18, 53],
#   'backdrop_path': '/A1S9fBzc4Wepc6onnCd9eVR2FLp.jpg',
#   'adult': False,
#   'overview': "On his first day on the job as a narcotics officer, a rookie cop works with a rogue detective who isn't what he appears.",
#   'release_date': '2001-10-05'},
#  {'vote_count': 0,
#   'id': 86316,
#   'video': False,
#   'vote_average': 0,
#   'title': 'Training Day',
#   'popularity': 0.6,
#   'poster_path': None,
#   'original_language': 'en',
#   'original_title': 'Training Day',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'TRAINING DAY is a half hour educational, inspirational, hip and fun sports show revealing how top, famous athletes, transform themselves from an average to super human. Creator, Director and host Flo Vinger will spend a day and training with these top athletes.',
#   'release_date': '2010-07-01'},
#  {'vote_count': 0,
#   'id': 358530,
#   'video': False,
#   'vote_average': 0,
#   'title': "Taro's Early Training Days",
#   'popularity': 0.6,
#   'poster_path': '/vuFTmAzeU897UwnWzndm6EQYH3Q.jpg',
#   'original_language': 'ja',
#   'original_title': '日の丸太郎～武者修行の巻～',
#   'genre_ids': [],
#   'backdrop_path': None,
#   'adult': False,
#   'overview': 'The hero Taro attempts to rescue a kidnapped girl from a bandit. Short film from 1936.',
#   'release_date': '1936-09-06'},
#  ...]

# %%
# checking types of data in results2 
types1 = []
for i in range(len(results2)):
    types1.append(type(results2[i]))

# %%
types1
# Out:
# [dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  dict,
#  ...]

# %%
# create dataframe of API data
movies_all = pd.DataFrame(results2)

# %%
movies_all.head()
# Out:
#    adult                     backdrop_path        genre_ids      id  \
# 0  False  /b0Zlbk19oTLjKPvb807suPFKBtN.jpg  [16, 35, 10751]    7443
# 1  False                              None             [16]  520758
# 2  False                              None               []  495607
# 3  False  /evNvMSUYYjZBluXuZEV9JpqNUel.jpg  [18, 35, 10749]   10697
# 4  False   /WeDJNcoIJDC6FvcC19dEHz09XR.jpg      [99, 10751]   41276
#
#   original_language                                     original_title  \
# 0                en                                        Chicken Run
# 1                en                                      Chicken Run 2
# 2                en  Running Around Like A Chicken With Its Head Cu...
# 3                fr                                 Le Goût des autres
# 4                en               The Life and Times of Hank Greenberg
#
#                                             overview  popularity  \
# 0  Having been hopelessly repressed and facing ev...      13.991
# 1          A sequel to the 2000 film, "Chicken Run."       1.462
# 2  Les Blank's first student film, made while at ...       0.600
# 3  Agnès Jaoui co-writes and directs this romanti...       5.907
# 4  The story of Baseball Hall-of-Famer Hank Green...       0.600
#
#                         poster_path release_date  \
# 0  /z0MafJgUnVyVbczicYMkPKKHkBi.jpg   2000-06-21
# 1  /wQJW29RIMFQFV46eTLLmTrorjDB.jpg   2020-06-12
# 2  /vNTe1R0zg9kEV8bBLEpdovb5Zvr.jpg   1960-01-01
# 3  /k9R6Omadvp57EoQ4x9nNneig1Nv.jpg   2000-03-01
# 4  /q5L7XLJ4ylDAs0txMMREbwuoudD.jpg   2000-01-12
#
#                                                title  video  vote_average  \
# 0                                        Chicken Run  False           6.6
# 1                                      Chicken Run 2  False           0.0
# 2  Running Around Like A Chicken With Its Head Cu...  False           0.0
# 3                                The Taste of Others  False           6.7
# 4               The Life and Times of Hank Greenberg  False           6.0
#
#    vote_count
# 0        2438
# 1           0
# 2           0
# 3          97
# 4           6

# %%
# remove unnecessary columns from dataframe
movies_all = movies_all.drop(['adult', 'backdrop_path', 'genre_ids', 'original_language', 'original_title', 'overview', 'poster_path', 'video'], axis=1)

# %%
# convert release date column into datetime and separate the year and month into their own columns
movies_all.release_date = pd.to_datetime(movies_all['release_date'])
movies_all['release_year'] = movies_all.release_date.dt.year
movies_all['release_month'] = movies_all.release_date.dt.month

# %% [markdown]
# ### Move API DataFrame Into CSV File ###

# %%
# convert movies_all dataframe to csv
movies_all.to_csv('tmdb_data.csv')

# %%
movies_all.head()
# Out:
#        id  popularity release_date  \
# 0    7443      13.991   2000-06-21
# 1  520758       1.462   2020-06-12
# 2  495607       0.600   1960-01-01
# 3   10697       5.907   2000-03-01
# 4   41276       0.600   2000-01-12
#
#                                                title  vote_average  \
# 0                                        Chicken Run           6.6
# 1                                      Chicken Run 2           0.0
# 2  Running Around Like A Chicken With Its Head Cu...           0.0
# 3                                The Taste of Others           6.7
# 4               The Life and Times of Hank Greenberg           6.0
#
#    vote_count  release_year  release_month
# 0        2438        2000.0            6.0
# 1           0        2020.0            6.0
# 2           0        1960.0            1.0
# 3          97        2000.0            3.0
# 4           6        2000.0            1.0

# %% [markdown]
# ### Merge API Data With Other Data ###

# %%
RT = pd.read_csv('RT_all.csv')

# %%
RT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1202 entries, 0 to 1201
# Data columns (total 21 columns):
# Unnamed: 0              1202 non-null int64
# Title                   1202 non-null object
# Director                1202 non-null object
# Writers                 0 non-null float64
# Release Date            1202 non-null object
# Revenue                 1202 non-null object
# Actors                  0 non-null float64
# Wrters                  1202 non-null object
# Unnamed: 0.1            1099 non-null float64
# Movie Title             1099 non-null object
# Review                  1099 non-null object
# Number of RT Reviews    1099 non-null float64
# Year                    1099 non-null float64
# movie_ID                717 non-null object
# movie_title             717 non-null object
# year                    717 non-null float64
# genres                  717 non-null object
# avg_rating              717 non-null float64
# numVotes                717 non-null float64
# directorID              717 non-null object
# director_name           636 non-null object
# dtypes: float64(8), int64(1), object(12)
# memory usage: 197.3+ KB

# %%
# remove duplicates based on title
RT = RT.drop_duplicates(subset=['Title'])

# %%
RT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1202 entries, 0 to 1201
# Data columns (total 21 columns):
# Unnamed: 0              1202 non-null int64
# Title                   1202 non-null object
# Director                1202 non-null object
# Writers                 0 non-null float64
# Release Date            1202 non-null object
# Revenue                 1202 non-null object
# Actors                  0 non-null float64
# Wrters                  1202 non-null object
# Unnamed: 0.1            1099 non-null float64
# Movie Title             1099 non-null object
# Review                  1099 non-null object
# Number of RT Reviews    1099 non-null float64
# Year                    1099 non-null float64
# movie_ID                717 non-null object
# movie_title             717 non-null object
# year                    717 non-null float64
# genres                  717 non-null object
# avg_rating              717 non-null float64
# numVotes                717 non-null float64
# directorID              717 non-null object
# director_name           636 non-null object
# dtypes: float64(8), int64(1), object(12)
# memory usage: 206.6+ KB

# %%
# merge dataframes
final_movies = pd.merge(RT, movies_all, left_on='Title', right_on='title', how='left', left_index=True)

# %%
final_movies.head()
# Out:
#       Unnamed: 0                                 Title  \
# 0              0                           Chicken Run
# 3              2                   The Taste of Others
# 812            2                   The Taste of Others
# 4              3  The Life and Times of Hank Greenberg
# 5757           3  The Life and Times of Hank Greenberg
#
#                          Director  Writers  Release Date  \
# 0     ['Peter Lord', 'Nick Park']      NaN  Jun 21, 2000
# 3                 ['Agnès Jaoui']      NaN   Jan 1, 2000
# 812               ['Agnès Jaoui']      NaN   Jan 1, 2000
# 4               ['Aviva Kempner']      NaN  Jan 12, 2000
# 5757            ['Aviva Kempner']      NaN  Jan 12, 2000
#
#                                                 Revenue  Actors  \
# 0                                          $106,604,314     NaN
# 3     \n\n                                112 minute...     NaN
# 812   \n\n                                112 minute...     NaN
# 4     \n\n                                89 minutes...     NaN
# 5757  \n\n                                89 minutes...     NaN
#
#                                        Wrters  Unnamed: 0.1  \
# 0     ['Jack Rosenthal', 'Karey Kirkpatrick']           0.0
# 3        ['Jean-Pierre Bacri', 'Agnès Jaoui']           NaN
# 812      ['Jean-Pierre Bacri', 'Agnès Jaoui']           NaN
# 4                           ['Aviva Kempner']           3.0
# 5757                        ['Aviva Kempner']           3.0
#
#                                Movie Title  ...           directorID  \
# 0                              Chicken Run  ...  nm0520485,nm0661910
# 3                                      NaN  ...                  NaN
# 812                                    NaN  ...                  NaN
# 4     The Life and Times of Hank Greenberg  ...                  NaN
# 5757  The Life and Times of Hank Greenberg  ...                  NaN
#
#       director_name       id popularity release_date  \
# 0               NaN   7443.0     13.991   2000-06-21
# 3               NaN  10697.0      5.907   2000-03-01
# 812             NaN  10697.0      5.907   2000-03-01
# 4               NaN  41276.0      0.600   2000-01-12
# 5757            NaN  41276.0      0.600   2000-01-12
#
#                                      title vote_average  vote_count  \
# 0                              Chicken Run          6.6      2438.0
# 3                      The Taste of Others          6.7        97.0
# 812                    The Taste of Others          6.7        97.0
# 4     The Life and Times of Hank Greenberg          6.0         6.0
# 5757  The Life and Times of Hank Greenberg          6.0         6.0
#
#       release_year release_month
# 0           2000.0           6.0
# 3           2000.0           3.0
# 812         2000.0           3.0
# 4           2000.0           1.0
# 5757        2000.0           1.0
#
# [5 rows x 29 columns]

# %%
final_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1982 entries, 0 to 10928
# Data columns (total 29 columns):
# Unnamed: 0              1982 non-null int64
# Title                   1982 non-null object
# Director                1982 non-null object
# Writers                 0 non-null float64
# Release Date            1982 non-null object
# Revenue                 1982 non-null object
# Actors                  0 non-null float64
# Wrters                  1982 non-null object
# Unnamed: 0.1            1822 non-null float64
# Movie Title             1822 non-null object
# Review                  1822 non-null object
# Number of RT Reviews    1822 non-null float64
# Year                    1822 non-null float64
# movie_ID                1272 non-null object
# movie_title             1272 non-null object
# year                    1272 non-null float64
# genres                  1272 non-null object
# avg_rating              1272 non-null float64
# numVotes                1272 non-null float64
# directorID              1272 non-null object
# director_name           1136 non-null object
# id                      1830 non-null float64
# popularity              1830 non-null float64
# release_date            1802 non-null datetime64[ns]
# title                   1830 non-null object
# vote_average            1830 non-null float64
# vote_count              1830 non-null float64
# release_year            1802 non-null float64
# release_month           1802 non-null float64
# dtypes: datetime64[ns](1), float64(14), int64(1), object(13)
# memory usage: 464.5+ KB

# %%
# drop unnecessary columns
final_movies = final_movies.drop(['Unnamed: 0', 'Writers', 'Actors', 'Unnamed: 0.1', 'Movie Title', 'movie_ID', 'movie_title', 'title', 'year', 'directorID', 'director_name', 'id', 'release_date', 'release_year'], axis=1)

# %%
final_movies.head()
# Out:
#                                      Title                     Director  \
# 0                              Chicken Run  ['Peter Lord', 'Nick Park']
# 3                      The Taste of Others              ['Agnès Jaoui']
# 812                    The Taste of Others              ['Agnès Jaoui']
# 4     The Life and Times of Hank Greenberg            ['Aviva Kempner']
# 5757  The Life and Times of Hank Greenberg            ['Aviva Kempner']
#
#       Release Date                                            Revenue  \
# 0     Jun 21, 2000                                       $106,604,314
# 3      Jan 1, 2000  \n\n                                112 minute...
# 812    Jan 1, 2000  \n\n                                112 minute...
# 4     Jan 12, 2000  \n\n                                89 minutes...
# 5757  Jan 12, 2000  \n\n                                89 minutes...
#
#                                        Wrters Review  Number of RT Reviews  \
# 0     ['Jack Rosenthal', 'Karey Kirkpatrick']    97%                 171.0
# 3        ['Jean-Pierre Bacri', 'Agnès Jaoui']    NaN                   NaN
# 812      ['Jean-Pierre Bacri', 'Agnès Jaoui']    NaN                   NaN
# 4                           ['Aviva Kempner']    97%                  65.0
# 5757                        ['Aviva Kempner']    97%                  65.0
#
#         Year                      genres  avg_rating  numVotes  popularity  \
# 0     2000.0  Adventure,Animation,Comedy         7.0  162266.0      13.991
# 3        NaN                         NaN         NaN       NaN       5.907
# 812      NaN                         NaN         NaN       NaN       5.907
# 4     2000.0                         NaN         NaN       NaN       0.600
# 5757  2000.0                         NaN         NaN       NaN       0.600
#
#       vote_average  vote_count  release_month
# 0              6.6      2438.0            6.0
# 3              6.7        97.0            3.0
# 812            6.7        97.0            3.0
# 4              6.0         6.0            1.0
# 5757           6.0         6.0            1.0

# %%
final_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1982 entries, 0 to 10928
# Data columns (total 15 columns):
# Title                   1982 non-null object
# Director                1982 non-null object
# Release Date            1982 non-null object
# Revenue                 1982 non-null object
# Wrters                  1982 non-null object
# Review                  1822 non-null object
# Number of RT Reviews    1822 non-null float64
# Year                    1822 non-null float64
# genres                  1272 non-null object
# avg_rating              1272 non-null float64
# numVotes                1272 non-null float64
# popularity              1830 non-null float64
# vote_average            1830 non-null float64
# vote_count              1830 non-null float64
# release_month           1802 non-null float64
# dtypes: float64(8), object(7)
# memory usage: 247.8+ KB

# %%
# convert all values in dataframe from json strings
if not np.nan:
    final_moviesl.applymap(lambda x : ast.literal_eval(x))
else:
    pass

# %%
# remove duplicates based on title
final_movies = final_movies.drop_duplicates(subset=['Title'])

# %%
final_movies.head()
# Out:
#                                       Title                     Director  \
# 0                               Chicken Run  ['Peter Lord', 'Nick Park']
# 3                       The Taste of Others              ['Agnès Jaoui']
# 4      The Life and Times of Hank Greenberg            ['Aviva Kempner']
# 5                                     Yi Yi              ['Edward Yang']
# 10956                   You Can Count On Me         ['Kenneth Lonergan']
#
#        Release Date                                            Revenue  \
# 0      Jun 21, 2000                                       $106,604,314
# 3       Jan 1, 2000  \n\n                                112 minute...
# 4      Jan 12, 2000  \n\n                                89 minutes...
# 5       Oct 6, 2000  \n\n                                173 minute...
# 10956  Nov 10, 2000                                         $8,409,329
#
#                                         Wrters Review  Number of RT Reviews  \
# 0      ['Jack Rosenthal', 'Karey Kirkpatrick']    97%                 171.0
# 3         ['Jean-Pierre Bacri', 'Agnès Jaoui']    NaN                   NaN
# 4                            ['Aviva Kempner']    97%                  65.0
# 5                              ['Edward Yang']    96%                  83.0
# 10956                     ['Kenneth Lonergan']    95%                 103.0
#
#          Year                      genres  avg_rating  numVotes  popularity  \
# 0      2000.0  Adventure,Animation,Comedy         7.0  162266.0      13.991
# 3         NaN                         NaN         NaN       NaN       5.907
# 4      2000.0                         NaN         NaN       NaN       0.600
# 5      2000.0               Drama,Romance         8.1   16786.0       6.590
# 10956  2000.0                         NaN         NaN       NaN         NaN
#
#        vote_average  vote_count  release_month
# 0               6.6      2438.0            6.0
# 3               6.7        97.0            3.0
# 4               6.0         6.0            1.0
# 5               8.0       156.0            9.0
# 10956           NaN         NaN            NaN

# %%
final_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1202 entries, 0 to 10928
# Data columns (total 15 columns):
# Title                   1202 non-null object
# Director                1202 non-null object
# Release Date            1202 non-null object
# Revenue                 1202 non-null object
# Wrters                  1202 non-null object
# Review                  1099 non-null object
# Number of RT Reviews    1099 non-null float64
# Year                    1099 non-null float64
# genres                  717 non-null object
# avg_rating              717 non-null float64
# numVotes                717 non-null float64
# popularity              1050 non-null float64
# vote_average            1050 non-null float64
# vote_count              1050 non-null float64
# release_month           1048 non-null float64
# dtypes: float64(8), object(7)
# memory usage: 150.2+ KB

# %%
final_movies = final_movies.rename({'Wrters':'Writers', 'Review':'Rotten Tomatoes Review', 'genres':'Genres', 'avg_rating': 'Average IMDB Rating', 'numVotes': 'Number of IMDB Votes', 'popularity': 'Popularity', 'vote_average':'Average TMDB Rating', 'vote_count':'Number of TMDB Votes', 'release_month':'Release Month'}, axis=1)

# %%
final_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1202 entries, 0 to 10928
# Data columns (total 15 columns):
# Title                     1202 non-null object
# Director                  1202 non-null object
# Release Date              1202 non-null object
# Revenue                   1202 non-null object
# Writers                   1202 non-null object
# Rotten Tomatoes Review    1099 non-null object
# Number of RT Reviews      1099 non-null float64
# Year                      1099 non-null float64
# Genres                    717 non-null object
# Average IMDB Rating       717 non-null float64
# Number of IMDB Votes      717 non-null float64
# Popularity                1050 non-null float64
# Average TMDB Rating       1050 non-null float64
# Number of TMDB Votes      1050 non-null float64
# Release Month             1048 non-null float64
# dtypes: float64(8), object(7)
# memory usage: 150.2+ KB

# %%
# change dtypes of columns
final_movies['Number of RT Reviews'] = final_movies['Number of RT Reviews'].astype('int64', errors='ignore')
final_movies['Year'] = final_movies['Year'].astype('int64', errors='ignore')
final_movies['Number of TMDB Votes'] = final_movies['Number of TMDB Votes'].astype('int64', errors='ignore')
final_movies['Release Month'] = final_movies['Release Month'].astype('int64', errors='ignore')
final_movies['Number of IMDB Votes'] = final_movies['Number of IMDB Votes'].astype('int64', errors='ignore')

# %%
# move final overall merged movies dataframe to csv file
final_movies.to_csv('movies_final.csv')

# %% [markdown]
# ### Move Data into SQL Database ###

# %%
# convert dataframe into sql database
connection = sqlite3.connect('movies_final.db')
cursor = connection.cursor()

# %%
# move pandas dataframe of overall merged movies data to sql database
final_movies.to_sql('movies_final', connection)

# %%
cursor.execute('''SELECT Title FROM movies_final;''').fetchall()
# Out:
# [('Chicken Run',),
#  ('The Taste of Others',),
#  ('The Life and Times of Hank Greenberg',),
#  ('Yi Yi',),
#  ('You Can Count On Me',),
#  ('Memento',),
#  ('Best in Show',),
#  ('Croupier',),
#  ('Dark Days',),
#  ('Not One Less',),
#  ('The Filth and the Fury',),
#  ('Almost Famous',),
#  ('Cast Away',),
#  ('Sexy Beast',),
#  ('Girlfight',),
#  ('State and Main',),
#  ('Meet the Parents',),
#  ('Erin Brockovich',),
#  ('Billy Elliot',),
#  ('Nico and Dani',),
#  ('Battle Royale',),
#  ('Nurse Betty',),
#  ('Thirteen Days',),
#  ('Chunhyangdyun',),
#  ('Shadow of the Vampire',),
#  ('Wonder Boys',),
#  ('George Washington',),
#  ('Merci pour le chocolat',),
#  ('Love and Basketball',),
#  ('Pollock',),
#  ('Fantasia 2000',),
#  ('Lakeboat',),
#  ('Requiem for a Dream',),
#  ('Shanghai Noon',),
#  ('The Vertical Ray of the Sun',),
#  ('Gladiator',),
#  ('Space Cowboys',),
#  ('Quills',),
#  ('Keep the River on Your Right',),
#  ('Finding Forrester',),
#  ('Remember the Titans',),
#  ('Tigerland',),
#  ('Sunshine',),
#  ('My Dog Skip',),
#  ('The Big Kahuna',),
#  ('Code Unknown',),
#  ('Unbreakable',),
#  ('Frequency',),
#  ('American Psycho',),
#  ('Keeping the Faith',),
#  ('Shadow Magic',),
#  ('Dancer in the Dark',),
#  ('Grateful Dawg',),
#  ('Timecode',),
#  ('About Adam',),
#  ('Small Time Crooks',),
#  ('Bring It On',),
#  ('Anywhere but Here',),
#  ('Chocolat',),
#  ('The Patriot',),
#  ('Der Krieger und die Kaiserin',),
#  ('Return to Me',),
#  ('Wonderland',),
#  ('The Tigger Movie',),
#  ('Pitch Black',),
#  ('Alice et Martin',),
#  ('Kikujiro',),
#  ('Godzilla 2000',),
#  ('Groove',),
#  ('The Dish',),
#  ('Werckmeister Harmonies',),
#  ('Time Out',),
#  ('In the Bedroom',),
#  ('Ghost World',),
#  ('Spy Kids',),
#  ('The Endurance',),
#  ('Y Tu Mama Tambien',),
#  ('Hedwig and the Angry Inch',),
#  ('Amores Perros',),
#  ('Shrek',),
#  ('Mostly Martha',),
#  ('The Gleaners and I',),
#  ('Our Song',),
#  ('Together',),
#  ('Dinner Rush',),
#  ('Divided We Fall',),
#  ('Gosford Park',),
#  ('Life And Debt',),
#  ('Donnie Darko',),
#  ('Italian for Beginners',),
#  ('Ginger Snaps',),
#  ('101 Reykjavik',),
#  ('La Cienaga',),
#  ('Va Savoir',),
#  ('Calle 54',),
#  ('Nowhere in Africa',),
#  ('Faithless',),
#  ('Thirteen Conversations About One Thing',),
#  ('Little Otik',),
#  ('Waking Life',),
#  ('Diamond Men',),
#  ('Iris',),
#  ('Lumumba',),
#  ('Jump Tomorrow',),
#  ('The Pledge',),
#  ('Black Hawk Down',),
#  ('A Beautiful Mind',),
#  ('Tape',),
#  ('Our Lady of the Assassins',),
#  ('Snatch',),
#  ('Joy Ride',),
#  ('Training Day',),
#  ('Brotherhood of the Wolf',),
#  ('Buffalo Soldiers',),
#  ('Songcatcher',),
#  ('Me You Them',),
#  ('Tortilla Soup',),
#  ('Before Night Falls',),
#  ('The Piano Teacher',),
#  ('Fat Girl',),
#  ('Behind the Sun',),
#  ('Made',),
#  ('Chopper',),
#  ('Baby Boy',),
#  ('Legally Blonde',),
#  ('Spirited Away',),
#  ('Catch Me If You Can',),
#  ('The Pianist',),
#  ('Bowling for Columbine',),
#  ('Read My Lips',),
#  ('Minority Report',),
#  ('About a Boy',),
#  ('Monsoon Wedding',),
#  ('Spider-Man',),
#  ('Promises',),
#  ('Open Hearts',),
#  ('Talk to Her',),
#  ('Infernal Affairs',),
#  ('Bloody Sunday',),
#  ('Nine Queens',),
#  ('Standing in the Shadows of Motown',),
#  ('Alias Betty',),
#  ('Lantana',),
#  ('Chicago',),
#  ('The Weather Underground',),
#  ('Murderous Maids',),
#  ('Russian Ark',),
#  ('The Girl From Paris',),
#  ('Roger Dodger',),
#  ('About Schmidt',),
#  ('Baran',),
#  ('Late Marriage',),
#  ('I Am Trying to Break Your Heart',),
#  ('Harry Potter and the Chamber of Secrets',),
#  ('Springtime in a Small Town',),
#  ('24 Hour Party People',),
#  ('Narc',),
#  ('The Rookie',),
#  ('Lawless Heart',),
#  ('Son of the Bride',),
#  ('One Hour Photo',),
#  ('Road to Perdition',),
#  ('Kissing Jessica Stein',),
#  ('Elling',),
#  ('The Royal Tenenbaums',),
#  ('Real Women Have Curves',),
#  ('La Stanza del Figlio',),
#  ('Morvern Callar',),
#  ('Barbershop',),
#  ('The Believer',),
#  ('Stuart Little 2',),
#  ('Drumline',),
#  ('Satin Rouge',),
#  ('Better Luck Tomorrow',),
#  ('Antwone Fisher',),
#  ('Secret Ballot',),
#  ('Sunshine State',),
#  ('Gigantic',),
#  ('8 Women',),
#  ('Tully',),
#  ('Biggie and Tupac',),
#  ('Ice Age',),
#  ('Nicholas Nickleby',),
#  ('8 Mile',),
#  ('Changing Lanes',),
#  ('Last Orders',),
#  ('Tadpole',),
#  ('Undercover Brother',),
#  ('Secretary',),
#  ('Panic Room',),
#  ('Gangs of New York',),
#  ('Signs',),
#  ('Igby Goes Down',),
#  ('Warm Water Under a Red Bridge',),
#  ('My Big Fat Greek Wedding',),
#  ('Frida',),
#  ('Comedian',),
#  ('Finding Nemo',),
#  ('Lost In Translation',),
#  ('Capturing the Friedmans',),
#  ('American Splendor',),
#  ('Sweet Sixteen',),
#  ('Raising Victor Vargas',),
#  ('Bus 174',),
#  ('Winged Migration',),
#  ('To Be and to Have',),
#  ('The Triplets of Belleville',),
#  ('Dirty Pretty Things',),
#  ('Festival Express',),
#  ('School of Rock',),
#  ('Los Angeles Plays Itself',),
#  ('Lost in La Mancha',),
#  ('Shattered Glass',),
#  ('Whale Rider',),
#  ('The Man on the Train',),
#  ('Far From Heaven',),
#  ('In America',),
#  ('Mystic River',),
#  ('Saraband',),
#  ('Stevie',),
#  ('28 Days Later',),
#  ('A Mighty Wind',),
#  ('Tokyo Godfathers',),
#  ('Freaky Friday',),
#  ('In This World',),
#  ('Bend It like Beckham',),
#  ('Intimate Strangers',),
#  ('Elf',),
#  ('Funny Ha Ha',),
#  ('Pieces of April',),
#  ('Noi the Albino',),
#  ('Ten',),
#  ('Matchstick Men',),
#  ('The Secret Lives of Dentists',),
#  ('Swimming Pool',),
#  ('A Tale of Two Sisters',),
#  ('Lilja 4-ever',),
#  ('Gloomy Sunday',),
#  ('21 Grams',),
#  ('Thirteen',),
#  ('Bad Santa',),
#  ('Stone Reader',),
#  ('Open Range',),
#  ('Confessions of a Dangerous Mind',),
#  ('Chihwaseon',),
#  ('25th Hour',),
#  ('Seabiscuit',),
#  ('Step Into Liquid',),
#  ('Ghosts of the Abyss',),
#  ('Blue Car',),
#  ('Charlotte Sometimes',),
#  ('Mondays in the Sun',),
#  ('Owning Mahowny',),
#  ('Friday Night',),
#  ('I Capture the Castle',),
#  ('Bubba Ho-Tep',),
#  ('Holes',),
#  ('The Matrix Reloaded',),
#  ('Intolerable Cruelty',),
#  ('House of Sand and Fog',),
#  ('Calendar Girls',),
#  ('Sideways',),
#  ('Maria Full of Grace',),
#  ('Hero',),
#  ('Eternal Sunshine Of The Spotless Mind',),
#  ('Before Sunset',),
#  ('Million Dollar Baby',),
#  ('Control Room',),
#  ('Osama',),
#  ('Shaun of the Dead',),
#  ('Touching the Void',),
#  ('Born Into Brothels',),
#  ('Harry Potter and the Prisoner of Azkaban',),
#  ('Since Otar Left',),
#  ('The Return',),
#  ('Super Size Me',),
#  ('The Story of the Weeping Camel',),
#  ('Hotel Rwanda',),
#  ('Vera Drake',),
#  ('Shrek 2',),
#  ('Lost Boys of Sudan',),
#  ('Kinsey',),
#  ('Riding Giants',),
#  ('My Architect',),
#  ('Downfall',),
#  ('Tarnation',),
#  ('Nobody Knows',),
#  ('Collateral',),
#  ('House of Flying Daggers',),
#  ('Kitchen Stories',),
#  ('Shaolin Soccer',),
#  ('Mean Creek',),
#  ('My Summer of Love',),
#  ('The Woodsman',),
#  ('Garden State',),
#  ('Bad Education',),
#  ('Last Life in the Universe',),
#  ('3-Iron',),
#  ('Touch The Sound',),
#  ('Mean Girls',),
#  ('Finding Neverland',),
#  ('In Good Company',),
#  ('Crimson Gold',),
#  ('The Sea Inside',),
#  ('The Motorcycle Diaries',),
#  ('Bright Leaves',),
#  ('Wilbur Wants to Kill Himself',),
#  ('Hellboy',),
#  ('Monster',),
#  ('Friday Night Lights',),
#  ('Ray',),
#  ('Red Lights',),
#  ('Miracle',),
#  ('Up and Down',),
#  ('Somersault',),
#  ('A Very Long Engagement',),
#  ('Two Brothers',),
#  ('The Machinist',),
#  ('Dawn of the Dead',),
#  ('Overnight',),
#  ('Being Julia',),
#  ('Brother to Brother',),
#  ('Murderball',),
#  ('March of the Penguins',),
#  ('Harry Potter and the Goblet of Fire',),
#  ('Grizzly Man',),
#  ('Kung Fu Hustle',),
#  ('Ushpizin',),
#  ('Brokeback Mountain',),
#  ('Duma',),
#  ('Travelers and Magicians',),
#  ('A History of Violence',),
#  ('Batman Begins',),
#  ('Broken Flowers',),
#  ('Head-On',),
#  ('Millions',),
#  ('King Kong',),
#  ('Up for Grabs',),
#  ('Water',),
#  ('Paradise Now',),
#  ('After Innocence',),
#  ('Junebug',),
#  ('New York Doll',),
#  ('Tony Takitani',),
#  ('Walk the Line',),
#  ('Turtles Can Fly',),
#  ('The Heart of the Game',),
#  ('Look at Me',),
#  ('Charlie and the Chocolate Factory',),
#  ('Tell Them Who You Are',),
#  ('Ong-Bak',),
#  ('Serenity',),
#  ('2046',),
#  ('Saving Face',),
#  ('Mysterious Skin',),
#  ('Gunner Palace',),
#  ('Mad Hot Ballroom',),
#  ('Rois et Reine',),
#  ('Cinderella Man',),
#  ('Three Times',),
#  ('Inside Deep Throat',),
#  ('Rize',),
#  ('13 Tzameti',),
#  ('De zaak Alzheimer',),
#  ('Sin City',),
#  ('Beyond the Gates',),
#  ('Me and You and Everyone We Know',),
#  ('Aliens of the Deep',),
#  ('Munich',),
#  ('Layer Cake',),
#  ('Dear Frankie',),
#  ('Oldboy',),
#  ('Rock School',),
#  ('Lost Embrace',),
#  ('War of the Worlds',),
#  ('Control',),
#  ('Match Point',),
#  ('Keane',),
#  ('Wedding Crashers',),
#  ('In Her Shoes',),
#  ('Zathura',),
#  ('Land of the Dead',),
#  ('Syriana',),
#  ('Balzac and the Little Chinese Seamstress',),
#  ('The Holy Girl',),
#  ('The Puffy Chair',),
#  ('Casino Royale',),
#  ('Deliver Us from Evil',),
#  ('The Departed',),
#  ('Children of Men',),
#  ('Blindsight',),
#  ('Wordplay',),
#  ('49 Up',),
#  ('Little Miss Sunshine',),
#  ('Letters from Iwo Jima',),
#  ('The Lives of Others',),
#  ('United 93',),
#  ('Volver',),
#  ('Offside',),
#  ('Half Nelson',),
#  ('Lassie',),
#  ('Venus',),
#  ('Blame It on Fidel',),
#  ('Inside Man',),
#  ('Notes on a Scandal',),
#  ('Iraq in Fragments',),
#  ('Who Killed the Electric Car?',),
#  ('Thank You for Smoking',),
#  ('Stephanie Daley',),
#  ('The Descent',),
#  ('Slither',),
#  ('Jesus Camp',),
#  ('Akeelah and the Bee',),
#  ('Man Push Cart',),
#  ('Maxed Out',),
#  ('El Aura',),
#  ('The Ground Truth',),
#  ('This Film Is Not Yet Rated',),
#  ('Sweet Land',),
#  ('Air Guitar Nation',),
#  ('Paprika',),
#  ('Old Joy',),
#  ('Mutual Appreciation',),
#  ('Tsotsi',),
#  ('Little Children',),
#  ('Dreamgirls',),
#  ('The Year My Parents Went on Vacation',),
#  ('Sketches of Frank Gehry',),
#  ('Superman Returns',),
#  ('Come Early Morning',),
#  ('District B13',),
#  ('Brick',),
#  ('Rocky Balboa',),
#  ('Priceless',),
#  ('Riding Alone for Thousands of Miles',),
#  ('Taxidermia',),
#  ('The Devil Wears Prada',),
#  ('V for Vendetta',),
#  ('Happy Feet',),
#  ('Transamerica',),
#  ('House of Sand',),
#  ('Cars',),
#  ('Over the Hedge',),
#  ('Catch a Fire',),
#  ('Factotum',),
#  ('Ratatouille',),
#  ('Taxi to the Dark Side',),
#  ('No Country for Old Men',),
#  ('Once',),
#  ('Persepolis',),
#  ('Juno',),
#  ('Gone Baby Gone',),
#  ('Ten Canoes',),
#  ('Enchanted',),
#  ('Sicko',),
#  ('For the Bible Tells Me So',),
#  ('Killer of Sheep',),
#  ('Surfwise',),
#  ('Grbavica',),
#  ('No End in Sight',),
#  ('There Will Be Blood',),
#  ('Away From Her',),
#  ('Knocked Up',),
#  ('Hairspray',),
#  ('Zodiac',),
#  ('The Host',),
#  ('Hot Fuzz',),
#  ('Up the Yangtze',),
#  ('Triad Election',),
#  ('Nanking',),
#  ('Michael Clayton',),
#  ('My Kid Could Paint That',),
#  ('Waitress',),
#  ('Eastern Promises',),
#  ('This Is England',),
#  ('Rescue Dawn',),
#  ('Lake of Fire',),
#  ('U2 3D',),
#  ('Superbad',),
#  ('The Italian',),
#  ('God Grew Tired Of Us',),
#  ('The Orphanage',),
#  ('The Wind That Shakes the Barley',),
#  ('Must Read After My Death',),
#  ('Grindhouse',),
#  ('Atonement',),
#  ('Bridge to Terabithia',),
#  ('Shotgun Stories',),
#  ('Roman de gare',),
#  ('Starting Out in the Evening',),
#  ('Breach',),
#  ('Into Great Silence',),
#  ('2 Days in Paris',),
#  ('Red Road',),
#  ('Boy A',),
#  ('Live Free or Die Hard',),
#  ('Syndromes and a Century',),
#  ('Into the Wild',),
#  ('Rocket Science',),
#  ('American Gangster',),
#  ('Talk to Me',),
#  ('War Dance',),
#  ('Manufactured Landscapes',),
#  ('Harry Potter and the Order of the Phoenix',),
#  ('XXY',),
#  ('1408',),
#  ('The Dark Knight',),
#  ('The Wrestler',),
#  ('Man on Wire',),
#  ('Let the Right One In',),
#  ('WALL-E',),
#  ('Iron Man',),
#  ('Milk',),
#  ('The Class',),
#  ('Slumdog Millionaire',),
#  ('Waltz with Bashir',),
#  ('Trouble the Water',),
#  ('Happy-Go-Lucky',),
#  ('Gomorrah',),
#  ('Chop Shop',),
#  ('The Pool',),
#  ('Sugar',),
#  ('Bolt',),
#  ('Transsiberian',),
#  ('Ballast',),
#  ('Caramel',),
#  ('Kung Fu Panda',),
#  ('Frozen River',),
#  ('Wendy and Lucy',),
#  ('Rachel Getting Married',),
#  ('24 City',),
#  ('Tropic Thunder',),
#  ('In Bruges',),
#  ('Forgetting Sarah Marshall',),
#  ('Mongol',),
#  ('Shine a Light',),
#  ('Meduzot',),
#  ('Vicky Cristina Barcelona',),
#  ('Indiana Jones and the Kingdom of the Crystal Skull',),
#  ('Doubt',),
#  ('Two Lovers',),
#  ('JCVD',),
#  ('Burn After Reading',),
#  ('Beaufort',),
#  ('In Search of a Midnight Kiss',),
#  ('Cloverfield',),
#  ('Disgrace',),
#  ('Fifty Dead Men Walking',),
#  ('The Bank Job',),
#  ('Role Models',),
#  ('Standard Operating Procedure',),
#  ('Nothing But the Truth',),
#  ('Chicago 10',),
#  ('Yella',),
#  ('Miss Pettigrew Lives for a Day',),
#  ('Baghead',),
#  ('Appaloosa',),
#  ('Ashes of Time Redux',),
#  ('I Served the King of England',),
#  ('Un Secret',),
#  ('Afterschool',),
#  ('Body of War',),
#  ('Water Lilies',),
#  ('Quantum of Solace',),
#  ('The Incredible Hulk',),
#  ('American Teen',),
#  ('Up',),
#  ('Star Trek',),
#  ('Afghan Star',),
#  ('An Education',),
#  ('Drag Me to Hell',),
#  ('District 9',),
#  ('Up in the Air',),
#  ('In the Loop',),
#  ('Coraline',),
#  ('Sweetgrass',),
#  ('Inglourious Basterds',),
#  ('Revanche',),
#  ('Zombieland',),
#  ('Tulpan',),
#  ('Somers Town',),
#  ('Good Hair',),
#  ('Ponyo',),
#  ('Crazy Heart',),
#  ('Tokyo Sonata',),
#  ('Of Time and the City',),
#  ('Goodbye Solo',),
#  ('Moon',),
#  ('A Serious Man',),
#  ('La Nana',),
#  ('Adventureland',),
#  ('Every Little Step',),
#  ('Red Cliff',),
#  ('The Messenger',),
#  ('Il Divo',),
#  ('Etz Limon',),
#  ('500 Days of Summer',),
#  ('Avatar',),
#  ('Harry Potter and the Half-Blood Prince',),
#  ('The Girl with the Dragon Tattoo',),
#  ('Sin Nombre',),
#  ('Whip It',),
#  ('Me and Orson Welles',),
#  ('The White Ribbon',),
#  ('Paranormal Activity',),
#  ('Disneynature Earth',),
#  ('Treeless Mountain',),
#  ('Skin',),
#  ('Gran Torino',),
#  ('Bright Star',),
#  ('Pontypool',),
#  ('Soul Power',),
#  ('Broken Embraces',),
#  ('The Hangover',),
#  ('Black Dynamite',),
#  ('Bakjwi',),
#  ('Bandslam',),
#  ('Collapse',),
#  ('Invictus',),
#  ('It Might Get Loud',),
#  ('Humpday',),
#  ('We Live in Public',),
#  ('A Town Called Panic',),
#  ('Where the Wild Things Are',),
#  ('A Summer In Genoa',),
#  ('Toy Story 3',),
#  ('How to Train Your Dragon',),
#  ('The Social Network',),
#  ('True Grit',),
#  ('Inside Job',),
#  ('Waste Land',),
#  ('A Prophet',),
#  ('127 Hours',),
#  ('The Town',),
#  ('Animal Kingdom',),
#  ('The Kids Are All Right',),
#  ('Marwencol',),
#  ('Restrepo',),
#  ('Mother',),
#  ('Ajami',),
#  ('A Film Unfinished',),
#  ('Exit Through The Gift Shop',),
#  ('The Fighter',),
#  ('Another Year',),
#  ('Inception',),
#  ('Best Worst Movie',),
#  ('No One Knows About Persian Cats',),
#  ('Boxing Gym',),
#  ('Tangled',),
#  ('The Tillman Story',),
#  ('Fish Tank',),
#  ('Samson and Delilah',),
#  ('Let Me In',),
#  ('The Secret in Their Eyes',),
#  ('The Illusionist',),
#  ('Vincere',),
#  ('Black Swan',),
#  ('Lourdes',),
#  ('Dogtooth',),
#  ('Waiting for Superman',),
#  ('The Secret of Kells',),
#  ('Blue Valentine',),
#  ('Lebanon',),
#  ('Rabbit Hole',),
#  ('Alamar',),
#  ('Cropsey',),
#  ('Unstoppable',),
#  ('My Dog Tulip',),
#  ('Alle Anderen',),
#  ('Easy A',),
#  ('Buried',),
#  ('Please Give',),
#  ('Terribly Happy',),
#  ('Get Low',),
#  ('White Material',),
#  ('The Square',),
#  ('Farewell',),
#  ('Looking for Eric',),
#  ('Four Lions',),
#  ('The Art Of The Steal',),
#  ('I Am Love',),
#  ('North Face',),
#  ('Cyrus',),
#  ('Catfish',),
#  ('Nowhere Boy',),
#  ('Mademoiselle Chambon',),
#  ('City Island',),
#  ('Made in Dagenham',),
#  ('The Disappearance of Alice Creed',),
#  ('Fair Game',),
#  ('Cairo Time',),
#  ('Disneynature Oceans',),
#  ('Iron Man 2',),
#  ('Tiny Furniture',),
#  ('Mother and Child',),
#  ('Solitary Man',),
#  ('Countdown to Zero',),
#  ('Night Catches Us',),
#  ('Greenberg',),
#  ('How I Ended This Summer',),
#  ('The Girl on the Train',),
#  ('Nanny McPhee Returns',),
#  ('The Artist',),
#  ('Moneyball',),
#  ('The Muppets',),
#  ('Poetry',),
#  ('Le Havre',),
#  ('The Interrupters',),
#  ('Project Nim',),
#  ('Nostalgia for the Light',),
#  ('We Were Here',),
#  ('Bill Cunningham New York',),
#  ('Drive',),
#  ('Source Code',),
#  ('Cave of Forgotten Dreams',),
#  ('Hugo',),
#  ('Midnight in Paris',),
#  ('Born To Be Wild',),
#  ('Tomboy',),
#  ('Weekend',),
#  ('Arthur Christmas',),
#  ('The Arbor',),
#  ('Silent Souls',),
#  ('Take Shelter',),
#  ('Incendies',),
#  ('Martha Marcy May Marlene',),
#  ('Senna',),
#  ('Of Gods and Men',),
#  ('Attack the Block',),
#  ('Rango',),
#  ('The Four Times',),
#  ('City of Life and Death',),
#  ('Point Blank',),
#  ('Margin Call',),
#  ('Certified Copy',),
#  ('Submarine',),
#  ('The Trip',),
#  ('Buck',),
#  ('Uncle Boonmee Who Can Recall His Past Lives',),
#  ('The Ides of March',),
#  ('Cedar Rapids',),
#  ('Rise of the Planet of the Apes',),
#  ('Super 8',),
#  ('Tinker Tailor Soldier Spy',),
#  ('Beginners',),
#  ('The Lincoln Lawyer',),
#  ('Bobby Fischer Against The World',),
#  ('The Hedgehog',),
#  ('A Screaming Man',),
#  ('Terri',),
#  ('Even the Rain',),
#  ('My Week with Marilyn',),
#  ('Carancho',),
#  ('Circumstance',),
#  ('A Better Life',),
#  ('La princesse de Montpensier',),
#  ('Potiche',),
#  ('Mysteries of Lisbon',),
#  ('Trollhunter',),
#  ('Young Adult',),
#  ('Thor',),
#  ('Shame',),
#  ('The Skin I Live In',),
#  ('Skyfall',),
#  ('Looper',),
#  ('Moonrise Kingdom',),
#  ('Jiro Dreams of Sushi',),
#  ('Wake in Fright',),
#  ('How to Survive a Plague',),
#  ('The Cabin in the Woods',),
#  ('The Invisible War',),
#  ('Silver Linings Playbook',),
#  ('Monsieur Lazhar',),
#  ('The Dark Knight Rises',),
#  ('The Kid with a Bike',),
#  ('This Is Not a Film',),
#  ('The Secret World of Arrietty',),
#  ('West of Memphis',),
#  ('The Loved Ones',),
#  ('The Island President',),
#  ('The Queen of Versailles',),
#  ('Marley',),
#  ('Searching for Sugar Man',),
#  ('The Sessions',),
#  ('Chasing Ice',),
#  ('Brooklyn Castle',),
#  ('5 Broken Cameras',),
#  ('Django Unchained',),
#  ('Headhunters',),
#  ('Holy Motors',),
#  ('Sing Your Song',),
#  ('The House I Live In',),
#  ('The Central Park Five',),
#  ('The Hunger Games',),
#  ('I Wish',),
#  ('Safety Not Guaranteed',),
#  ('Life of Pi',),
#  ('Side by Side',),
#  ('ParaNorman',),
#  ('Once Upon a Time in Anatolia',),
#  ('Beasts of the Southern Wild',),
#  ('Arbitrage',),
#  ('Compliance',),
#  ('Bernie',),
#  ('A Royal Affair',),
#  ('Wreck-it Ralph',),
#  ('Footnote',),
#  ('The Perks of Being a Wallflower',),
#  ('Chronicle',),
#  ('End of Watch',),
#  ('Keep the Lights On',),
#  ('Seven Psychopaths',),
#  ('Neil Young Journeys',),
#  ('Bully',),
#  ('The Turin Horse',),
#  ('Tabu',),
#  ('Polisse',),
#  ('Middle of Nowhere',),
#  ('Boy',),
#  ('Miss Bala',),
#  ('Starlet',),
#  ('Rundskop',),
#  ('The Impossible',),
#  ('Sleepwalk With Me',),
#  ('Magic Mike',),
#  ('Declaration of War',),
#  ('Snabba cash',),
#  ('Smashed',),
#  ('12 Years a Slave',),
#  ('Her',),
#  ('Short Term 12',),
#  ('Mud',),
#  ('Captain Phillips',),
#  ('20 Feet From Stardom',),
#  ('Wadjda',),
#  ('All Is Lost',),
#  ('American Hustle',),
#  ('Inside Llewyn Davis',),
#  ('Blackfish',),
#  ('Zero Dark Thirty',),
#  ('Enough Said',),
#  ('Fruitvale Station',),
#  ('56 Up',),
#  ('The Act Of Killing',),
#  ('Nebraska',),
#  ('Sound City',),
#  ('Call Me Kuchu',),
#  ('Frozen',),
#  ('Let The Fire Burn',),
#  ('Stories We Tell',),
#  ('A Hijacking',),
#  ('Muscle Shoals',),
#  ('Room 237',),
#  ('Frances Ha',),
#  ('Behind the Candelabra',),
#  ('Blue Jasmine',),
#  ('Lore',),
#  ('The Spectacular Now',),
#  ('The Gatekeepers',),
#  ('Blancanieves',),
#  ('I Am Divine',),
#  ('Cutie And The Boxer',),
#  ('The Crash Reel',),
#  ('Philomena',),
#  ('A Touch of Sin',),
#  ('Museum Hours',),
#  ('Blue Is The Warmest Color',),
#  ('Star Trek Into Darkness',),
#  ('The History Of Future Folk',),
#  ('The Sapphires',),
#  ('War Witch',),
#  ('Still Mine',),
#  ('The Great Beauty',),
#  ('Drug War',),
#  ('After Tiller',),
#  ('Mother Of George',),
#  ('Beyond The Hills',),
#  ('Caesar Must Die',),
#  ('The Conjuring',),
#  ('Gimme The Loot',),
#  ('The Punk Singer',),
#  ('Iron Man 3',),
#  ('Inequality For All',),
#  ('This Is the End',),
#  ('My Brother The Devil',),
#  ('Fill the Void',),
#  ('Upstream Color',),
#  ('In the House',),
#  ('The Way Way Back',),
#  ('Side Effects',),
#  ('Narco Cultura',),
#  ('Yossi',),
#  ('What Maisie Knew',),
#  ('Computer Chess',),
#  ('Hannah Arendt',),
#  ('We Are What We Are',),
#  ('Sightseers',),
#  ('Warm Bodies',),
#  ('At Berkeley',),
#  ('Berberian Sound Studio',),
#  ('From Up On Poppy Hill',),
#  ('The Patience Stone',),
#  ('The Place Beyond The Pines',),
#  ('Boyhood',),
#  ('The Babadook',),
#  ('Nightcrawler',),
#  ('The LEGO Movie',),
#  ('Life Itself',),
#  ('Snowpiercer',),
#  ('Guardians of the Galaxy',),
#  ('Leviathan',),
#  ('Starred Up',),
#  ('The Tale of the Princess Kaguya',),
#  ('The Grand Budapest Hotel',),
#  ('Dawn Of The Planet Of The Apes',),
#  ('The Missing Picture',),
#  ('Ida',),
#  ('Citizenfour',),
#  ('The Overnighters',),
#  ('Blue Ruin',),
#  ('Ilo Ilo',),
#  ('Gone Girl',),
#  ('The Imitation Game',),
#  ('Love Is Strange',),
#  ('A Girl Walks Home Alone at Night',),
#  ('The Lunchbox',),
#  ('How to Train Your Dragon 2',),
#  ('The Rocket',),
#  ('Finding Vivian Maier',),
#  ('Locke',),
#  ('Big Hero 6',),
#  ('Particle Fever',),
#  ('Manakamana',),
#  ('The Last of the Unjust',),
#  ('Obvious Child',),
#  ('National Gallery',),
#  ('Last Days in Vietnam',),
#  ('The Drop',),
#  ('Foxcatcher',),
#  ('Pride',),
#  ('Stranger by the Lake',),
#  ('Dear White People',),
#  ('The Normal Heart',),
#  ('John Wick',),
#  ('The Dance of Reality',),
#  ('The Wind Rises',),
#  ('Le Week-End',),
#  ('Mistaken for Strangers',),
#  ('A Most Wanted Man',),
#  ('Under the Skin',),
#  ('Top Five',),
#  ('Disneynature Bears',),
#  ('22 Jump Street',),
#  ('Only Lovers Left Alive',),
#  ('To Be Takei',),
#  ('Art and Craft',),
#  ('Venus in Fur',),
#  ('The Skeleton Twins',),
#  ('Omar',),
#  ('Night Moves',),
#  ('Cheap Thrills',),
#  ('A Field in England',),
#  ('The Kill Team',),
#  ('Closed Curtain',),
#  ('Siddharth',),
#  ('Alan Partridge',),
#  ('Adieu au langage',),
#  ('The Good Lie',),
#  ('Inside Out',),
#  ('Selma',),
#  ('Brooklyn',),
#  ('Creed',),
#  ('It Follows',),
#  ('Carol',),
#  ('Shaun the Sheep Movie',),
#  ('The Martian',),
#  ('Room',),
#  ('45 Years',),
#  ('Son of Saul',),
#  ('Amy',),
#  ('What We Do In The Shadows',),
#  ('Bridge of Spies',),
#  ('Anomalisa',),
#  ('Ex Machina',),
#  ('About Elly',),
#  ('The Look of Silence',),
#  ('Wild Tales',),
#  ('The Big Short',),
#  ('The Diary Of A Teenage Girl',),
#  ('Ingrid Bergman in Her Own Words',),
#  ('Court',),
#  ('Listen To Me Marlon',),
#  ('Theeb',),
#  ('Welcome To Leith',),
#  ('The Second Mother',),
#  ('Girlhood',),
#  ('Heart of a Dog',),
#  ('Appropriate Behavior',),
#  ('Steve Jobs',),
#  ('99 Homes',),
#  ...]

# %%
cursor.close()
connection.close()
